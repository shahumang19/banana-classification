# %% [markdown]
# #Tensorflow Object Detection with custom dataset in Google Colab
#
# Jupyter notebook providing steps to retrain a [ModelZoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md) model with custom dataset.
#
# It runs in [Google Colab](https://colab.research.google.com) using [Tensorflow Object Detection API](https://github.com/tensorflow/models/tree/master/research/object_detection).
#
# **Requirements are only dataset images and annotations file.**
#
# The code is compatible with Object Detection api updates in July 13 2018 [release](https://github.com/tensorflow/models/tree/master/research/object_detection#july-13-2018).
#
# **Colab Runtime type: Python2, GPU enabled.**

# %% [markdown]
# #Create Dataset
#
# I generated dataset annotations with [LabelImg](https://github.com/tzutalin/labelImg).
#
# Notebook train a model for one class object detection. It is possible to slightly modify notebook to train model for multiple classes.
#
# Before running notebook, we need to create dataset:
#
# 1.   Collect various pictures of objects to detect
# 2.   Rename image filenames with format `objectclass_seq.jpg`
# 3.   In LabelImg create annotation files. LabelImg saves annotations as XML files in PASCAL VOC format
# 4.   Create dataset.zip file having structure defined below
# 5.   Upload the zip file in your Google Drive
#
# Zip file structure:
# ```
# dataset.zip file
# |-images directory
#   |-image files (filename format: objectclass_seq.jpg)
# |-annotations directory
#   |-xmls directory
#     |-annotation files (filename format: objectclass_seq.xml)
# ```
#
# Where `objectclass` is the class name, `seq` is a sequence number (001, 002, 003, ...)
#
# Check my dataset.zip file as dataset example.

# %% [markdown]
# # Install required packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content
  
# !git clone --quiet https://github.com/tensorflow/models.git

# !apt-get install -qq protobuf-compiler python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib PyDrive

# !pip install -q pycocotools

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# !python object_detection/builders/model_builder_test.py
# Out:
# /content
# /content/models/research
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:374: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_experimental_model
# [       OK ] ModelBuilderTest.test_create_experimental_model
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTest.test_create_rfcn_model_from_config
# [       OK ] ModelBuilderTest.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_fpn_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_models_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTest.test_invalid_faster_rcnn_batchnorm_update
# [       OK ] ModelBuilderTest.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTest.test_invalid_first_stage_nms_iou_threshold
# [       OK ] ModelBuilderTest.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTest.test_invalid_model_config_proto
# [       OK ] ModelBuilderTest.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTest.test_invalid_second_stage_batch_size
# [       OK ] ModelBuilderTest.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTest.test_session
# [  SKIPPED ] ModelBuilderTest.test_session
# [ RUN      ] ModelBuilderTest.test_unknown_faster_rcnn_feature_extractor
# [       OK ] ModelBuilderTest.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTest.test_unknown_meta_architecture
# [       OK ] ModelBuilderTest.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTest.test_unknown_ssd_feature_extractor
# [       OK ] ModelBuilderTest.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 17 tests in 0.164s
#
# OK (skipped=1)

# %% [markdown]
# # Download and extract dataset
#
#
# *   Change name attribute in label_map, accordingly with objectclass filename.
# *   Substitute fileId value with your dataset.zip id in Google Drive. See [here](https://stackoverflow.com/a/48855034/9250875) my answer to get file id.

# %%
# %cd /datalab

# !echo "item {id: 1 name: 'banana'}" > label_map.pbtxt

fileId = '1_a9LcvCdxaHa7dGyx9IVB2AMUgGKsa81'

import os
from zipfile import ZipFile
from shutil import copy
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

fileName = fileId + '.zip'
downloaded = drive.CreateFile({'id': fileId})
downloaded.GetContentFile(fileName)
ds = ZipFile(fileName)
ds.extractall()
os.remove(fileName)
print('Extracted zip file ' + fileName)

image_files=os.listdir('images')
im_files=[x.split('.')[0] for x in image_files]
with open('annotations/trainval.txt', 'w') as text_file:
  for row in im_files:
    text_file.write(row + '\n')
# Out:
# /datalab
# Extracted zip file 1_a9LcvCdxaHa7dGyx9IVB2AMUgGKsa81.zip

# %% [markdown]
# #Empty png files
# Create empty png mask files to avoid error in create_pet_tf_record.py, they are not used in training model.

# %%
# %cd /datalab/annotations/

# !mkdir trimaps

from PIL import Image
image = Image.new('RGB', (640, 480))

for filename in os.listdir('xmls'):
  filename = os.path.splitext(filename)[0]
  image.save('trimaps/' + filename + '.png')
# Out:
# /datalab/annotations

# %% [markdown]
# # Create TFRecord

# %%
# %cd /datalab

# !python ../content/models/research/object_detection/dataset_tools/create_pet_tf_record.py --label_map_path=/datalab/label_map.pbtxt --data_dir=. --output_dir=. --num_shards=1

# !mv pet_faces_train.record-00000-of-00001 tf_train.record

# !mv pet_faces_val.record-00000-of-00001 tf_val.record
# Out:
# /datalab
# WARNING:tensorflow:From ../content/models/research/object_detection/dataset_tools/create_pet_tf_record.py:318: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/label_map_util.py:138: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1210 06:27:20.812428 140287484061568 module_wrapper.py:139] From /content/models/research/object_detection/utils/label_map_util.py:138: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# I1210 06:27:20.813328 140287484061568 create_pet_tf_record.py:273] Reading from Pet dataset.
# I1210 06:27:20.817519 140287484061568 create_pet_tf_record.py:288] 1132 training and 486 validation examples.
# WARNING:tensorflow:From /content/models/research/object_detection/dataset_tools/tf_record_creation_util.py:43: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W1210 06:27:20.817737 140287484061568 module_wrapper.py:139] From /content/models/research/object_detection/dataset_tools/tf_record_creation_util.py:43: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# I1210 06:27:20.817949 140287484061568 create_pet_tf_record.py:241] On image 0 of 1132
# /content/models/research/object_detection/utils/dataset_util.py:79: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   if not xml:
# I1210 06:27:21.666516 140287484061568 create_pet_tf_record.py:241] On image 100 of 1132
# I1210 06:27:22.510244 140287484061568 create_pet_tf_record.py:241] On image 200 of 1132
# I1210 06:27:23.363847 140287484061568 create_pet_tf_record.py:241] On image 300 of 1132
# I1210 06:27:24.217300 140287484061568 create_pet_tf_record.py:241] On image 400 of 1132
# I1210 06:27:25.065474 140287484061568 create_pet_tf_record.py:241] On image 500 of 1132
# I1210 06:27:25.906552 140287484061568 create_pet_tf_record.py:241] On image 600 of 1132
# I1210 06:27:26.770367 140287484061568 create_pet_tf_record.py:241] On image 700 of 1132
# I1210 06:27:27.620205 140287484061568 create_pet_tf_record.py:241] On image 800 of 1132
# I1210 06:27:28.528879 140287484061568 create_pet_tf_record.py:241] On image 900 of 1132
# I1210 06:27:29.385442 140287484061568 create_pet_tf_record.py:241] On image 1000 of 1132
# I1210 06:27:30.217622 140287484061568 create_pet_tf_record.py:241] On image 1100 of 1132
# I1210 06:27:30.494171 140287484061568 create_pet_tf_record.py:241] On image 0 of 486
# I1210 06:27:31.340463 140287484061568 create_pet_tf_record.py:241] On image 100 of 486
# I1210 06:27:32.193211 140287484061568 create_pet_tf_record.py:241] On image 200 of 486
# I1210 06:27:33.032583 140287484061568 create_pet_tf_record.py:241] On image 300 of 486
# I1210 06:27:33.924324 140287484061568 create_pet_tf_record.py:241] On image 400 of 486

# %% [markdown]
# # Download pretrained model
#
# Cell downloads **faster_rcnn_inception_v2_coco** model to use as starting checkpoint.
#
# To use another model from ModelZoo change MODEL var.

# %%
# %cd /datalab

import os
import shutil
import glob
import urllib
import tarfile

MODEL = 'faster_rcnn_inception_v2_coco_2018_01_28'
MODEL_FILE = MODEL + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
DEST_DIR = 'pretrained_model'

if not (os.path.exists(MODEL_FILE)):
  opener = urllib.request.URLopener()
  opener.retrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
  shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)
# Out:
# /datalab

# %% [markdown]
# # Edit model config file
# To you use a different pretrained model in step before, update accordingly filename var and re.sub functions in next cell.

# %%
# %cd /datalab

import re

#filename = '/content/datalab/pretrained_model/pipeline.config'
filename = '../content/models/research/object_detection/samples/configs/faster_rcnn_inception_v2_pets.config'
with open(filename) as f:
  s = f.read()
with open(filename, 'w') as f:
  s = re.sub('num_classes: 37', 'num_classes: 1', s)
  s = re.sub('PATH_TO_BE_CONFIGURED/model.ckpt', str(os.getcwd())+'/pretrained_model/model.ckpt', s)
  s = re.sub('PATH_TO_BE_CONFIGURED/pet_faces_train.record-\?\?\?\?\?-of-00010', str(os.getcwd())+'/tf_train.record', s)
  s = re.sub('PATH_TO_BE_CONFIGURED/pet_faces_val.record-\?\?\?\?\?-of-00010', str(os.getcwd())+'/tf_val.record', s)
  s = re.sub('PATH_TO_BE_CONFIGURED/pet_label_map.pbtxt', str(os.getcwd())+'/label_map.pbtxt', s)

  # s = re.sub('num_classes: 37', 'num_classes: 1', s)
  # s = re.sub('/content/datalab/pretrained_model/model.ckpt','/datalab/pretrained_model/model.ckpt', s)
  # s = re.sub('/content/datalab/tf_train.record','/datalab/tf_train.record', s)
  # s = re.sub('/content/datalab/tf_val.record', '/datalab/tf_val.record', s)
  # s = re.sub('/content/datalab/label_map.pbtxt', '/datalab/label_map.pbtxt', s)


  f.write(s)

print("*"*40,"\n")
print(s)
# Out:
# /datalab
# ****************************************
#
# # Faster R-CNN with Inception v2, configured for Oxford-IIIT Pets Dataset.
# # Users should configure the fine_tune_checkpoint field in the train config as
# # well as the label_map_path and input_path fields in the train_input_reader and
# # eval_input_reader. Search for "PATH_TO_BE_CONFIGURED" to find the fields that
# # should be configured.
#
# model {
#   faster_rcnn {
#     num_classes: 1
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 600
#         max_dimension: 1024
#       }
#     }
#     feature_extractor {
#       type: 'faster_rcnn_inception_v2'
#       first_stage_features_stride: 16
#     }
#     first_stage_anchor_generator {
#       grid_anchor_generator {
#         scales: [0.25, 0.5, 1.0, 2.0]
#         aspect_ratios: [0.5, 1.0, 2.0]
#         height_stride: 16
#         width_stride: 16
#       }
#     }
#     first_stage_box_predictor_conv_hyperparams {
#       op: CONV
#       regularizer {
#         l2_regularizer {
#           weight: 0.0
#         }
#       }
#       initializer {
#         truncated_normal_initializer {
#           stddev: 0.01
#         }
#       }
#     }
#     first_stage_nms_score_threshold: 0.0
#     first_stage_nms_iou_threshold: 0.7
#     first_stage_max_proposals: 300
#     first_stage_localization_loss_weight: 2.0
#     first_stage_objectness_loss_weight: 1.0
#     initial_crop_size: 14
#     maxpool_kernel_size: 2
#     maxpool_stride: 2
#     second_stage_box_predictor {
#       mask_rcnn_box_predictor {
#         use_dropout: false
#         dropout_keep_probability: 1.0
#         fc_hyperparams {
#           op: FC
#           regularizer {
#             l2_regularizer {
#               weight: 0.0
#             }
#           }
#           initializer {
#             variance_scaling_initializer {
#               factor: 1.0
#               uniform: true
#               mode: FAN_AVG
#             }
#           }
#         }
#       }
#     }
#     second_stage_post_processing {
#       batch_non_max_suppression {
#         score_threshold: 0.0
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 300
#       }
#       score_converter: SOFTMAX
#     }
#     second_stage_localization_loss_weight: 2.0
#     second_stage_classification_loss_weight: 1.0
#   }
# }
#
# train_config: {
#   batch_size: 1
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         manual_step_learning_rate {
#           initial_learning_rate: 0.0002
#           schedule {
#             step: 900000
#             learning_rate: .00002
#           }
#           schedule {
#             step: 1200000
#             learning_rate: .000002
#           }
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   gradient_clipping_by_norm: 10.0
#   fine_tune_checkpoint: "/datalab/pretrained_model/model.ckpt"
#   from_detection_checkpoint: true
#   load_all_detection_checkpoint_vars: true
#   # Note: The below line limits the training process to 200K steps, which we
#   # empirically found to be sufficient enough to train the pets dataset. This
#   # effectively bypasses the learning rate schedule (the learning rate will
#   # never decay). Remove the below line to train indefinitely.
#   num_steps: 200000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
# }
#
#
# train_input_reader: {
#   tf_record_input_reader {
#     input_path: "/datalab/tf_train.record"
#   }
#   label_map_path: "/datalab/label_map.pbtxt"
# }
#
# eval_config: {
#   metrics_set: "coco_detection_metrics"
#   num_examples: 1101
# }
#
# eval_input_reader: {
#   tf_record_input_reader {
#     input_path: "/datalab/tf_val.record"
#   }
#   label_map_path: "/datalab/label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
# }

# %% [markdown]
# # Train model
# Set num_train_steps and num_eval_steps values to change train and eval steps in training process.

# %%
# %cd /datalab

# !python /content/models/research/object_detection/model_main.py \
    --pipeline_config_path=/content/models/research/object_detection/samples/configs/faster_rcnn_inception_v2_pets.config \
    --model_dir=/content/drive/My\ Drive/datalab/trained \
    --alsologtostderr \
    --num_train_steps=10000 \
    --num_eval_steps=500
# Out:
# /datalab
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:374: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_main.py:109: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/config_util.py:102: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1210 09:24:11.613017 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/utils/config_util.py:102: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:628: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# W1210 09:24:11.615335 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:628: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W1210 09:24:11.615452 140533543180160 model_lib.py:629] Forced number of epochs for all eval validations to be 1.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/config_util.py:488: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1210 09:24:11.615549 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/utils/config_util.py:488: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Maybe overwriting train_steps: 10000
# I1210 09:24:11.615628 140533543180160 config_util.py:488] Maybe overwriting train_steps: 10000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1210 09:24:11.615689 140533543180160 config_util.py:488] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: 1
# I1210 09:24:11.615743 140533543180160 config_util.py:488] Maybe overwriting sample_1_of_n_eval_examples: 1
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I1210 09:24:11.615793 140533543180160 config_util.py:488] Maybe overwriting eval_num_epochs: 1
# INFO:tensorflow:Maybe overwriting load_pretrained: True
# I1210 09:24:11.615839 140533543180160 config_util.py:488] Maybe overwriting load_pretrained: True
# INFO:tensorflow:Ignoring config override key: load_pretrained
# I1210 09:24:11.615884 140533543180160 config_util.py:498] Ignoring config override key: load_pretrained
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W1210 09:24:11.615959 140533543180160 model_lib.py:645] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# INFO:tensorflow:create_estimator_and_inputs: use_tpu False, export_to_tpu False
# I1210 09:24:11.616020 140533543180160 model_lib.py:680] create_estimator_and_inputs: use_tpu False, export_to_tpu False
# INFO:tensorflow:Using config: {'_model_dir': '/content/drive/My Drive/datalab/trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fd01de8d518>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I1210 09:24:11.616357 140533543180160 estimator.py:212] Using config: {'_model_dir': '/content/drive/My Drive/datalab/trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fd01de8d518>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7fd01de8cc80>) includes params argument, but params are not passed to Estimator.
# W1210 09:24:11.616603 140533543180160 model_fn.py:630] Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7fd01de8cc80>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Not using Distribute Coordinator.
# I1210 09:24:11.617863 140533543180160 estimator_training.py:186] Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# I1210 09:24:11.618027 140533543180160 training.py:612] Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# I1210 09:24:11.618205 140533543180160 training.py:700] Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W1210 09:24:11.624056 140533543180160 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /content/models/research/object_detection/data_decoders/tf_example_decoder.py:182: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W1210 09:24:11.637511 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/data_decoders/tf_example_decoder.py:182: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/data_decoders/tf_example_decoder.py:197: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# W1210 09:24:11.637781 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/data_decoders/tf_example_decoder.py:197: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:64: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# W1210 09:24:11.650403 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/builders/dataset_builder.py:64: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1210 09:24:11.651377 140533543180160 dataset_builder.py:72] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:86: parallel_interleave (from tensorflow.contrib.data.python.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.parallel_interleave(...)`.
# W1210 09:24:11.656187 140533543180160 deprecation.py:323] From /content/models/research/object_detection/builders/dataset_builder.py:86: parallel_interleave (from tensorflow.contrib.data.python.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.parallel_interleave(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/data/python/ops/interleave_ops.py:77: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# W1210 09:24:11.656332 140533543180160 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/data/python/ops/interleave_ops.py:77: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:155: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1210 09:24:11.675570 140533543180160 deprecation.py:323] From /content/models/research/object_detection/builders/dataset_builder.py:155: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.logging.warn is deprecated. Please use tf.compat.v1.logging.warn instead.
#
# W1210 09:24:12.785763 140533543180160 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.logging.warn is deprecated. Please use tf.compat.v1.logging.warn instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.is_nan is deprecated. Please use tf.math.is_nan instead.
#
# W1210 09:24:19.011040 140533543180160 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.is_nan is deprecated. Please use tf.math.is_nan instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/ops.py:493: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1210 09:24:19.079553 140533543180160 deprecation.py:323] From /content/models/research/object_detection/utils/ops.py:493: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1210 09:24:20.954426 140533543180160 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# W1210 09:24:22.560162 140533543180160 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/inputs.py:166: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1210 09:24:23.200833 140533543180160 deprecation.py:323] From /content/models/research/object_detection/inputs.py:166: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.string_to_hash_bucket_fast is deprecated. Please use tf.strings.to_hash_bucket_fast instead.
#
# W1210 09:24:24.999607 140533543180160 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.string_to_hash_bucket_fast is deprecated. Please use tf.strings.to_hash_bucket_fast instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:158: batch_and_drop_remainder (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.batch(..., drop_remainder=True)`.
# W1210 09:24:25.512443 140533543180160 deprecation.py:323] From /content/models/research/object_detection/builders/dataset_builder.py:158: batch_and_drop_remainder (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.batch(..., drop_remainder=True)`.
# INFO:tensorflow:Calling model_fn.
# I1210 09:24:25.524478 140533543180160 estimator.py:1148] Calling model_fn.
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:168: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1210 09:24:25.541810 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:168: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:2784: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1210 09:24:25.550345 140533543180160 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:2784: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/models/research/object_detection/core/anchor_generator.py:171: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# W1210 09:24:26.843632 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/core/anchor_generator.py:171: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:24:26.849915 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:558: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# W1210 09:24:26.850231 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:558: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:24:26.863043 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1210 09:24:26.863352 140533543180160 convolutional_box_predictor.py:151] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /content/models/research/object_detection/box_coders/faster_rcnn_box_coder.py:82: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W1210 09:24:27.414021 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/box_coders/faster_rcnn_box_coder.py:82: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/minibatch_sampler.py:85: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# W1210 09:24:27.450017 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/core/minibatch_sampler.py:85: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/spatial_transform_ops.py:419: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W1210 09:24:27.638002 140533543180160 deprecation.py:506] From /content/models/research/object_detection/utils/spatial_transform_ops.py:419: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:191: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W1210 09:24:27.653599 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:191: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W1210 09:24:28.117827 140533543180160 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:24:28.119841 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:24:28.134056 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/variables_helper.py:179: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1210 09:24:28.156344 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/utils/variables_helper.py:179: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2768: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# W1210 09:24:28.156519 140533543180160 deprecation.py:323] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2768: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# WARNING:tensorflow:From /content/models/research/object_detection/utils/variables_helper.py:139: The name tf.train.NewCheckpointReader is deprecated. Please use tf.compat.v1.train.NewCheckpointReader instead.
#
# W1210 09:24:28.157470 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/utils/variables_helper.py:139: The name tf.train.NewCheckpointReader is deprecated. Please use tf.compat.v1.train.NewCheckpointReader instead.
#
# W1210 09:24:28.160809 140533543180160 variables_helper.py:154] Variable [SecondStageBoxPredictor/BoxEncodingPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[360]], model variable shape: [[4]]. This variable will not be initialized from the checkpoint.
# W1210 09:24:28.160939 140533543180160 variables_helper.py:154] Variable [SecondStageBoxPredictor/BoxEncodingPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1024, 360]], model variable shape: [[1024, 4]]. This variable will not be initialized from the checkpoint.
# W1210 09:24:28.161020 140533543180160 variables_helper.py:154] Variable [SecondStageBoxPredictor/ClassPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[91]], model variable shape: [[2]]. This variable will not be initialized from the checkpoint.
# W1210 09:24:28.161094 140533543180160 variables_helper.py:154] Variable [SecondStageBoxPredictor/ClassPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1024, 91]], model variable shape: [[1024, 2]]. This variable will not be initialized from the checkpoint.
# W1210 09:24:28.161735 140533543180160 variables_helper.py:157] Variable [global_step] is not available in checkpoint
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:353: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W1210 09:24:28.161926 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:353: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/losses.py:177: The name tf.losses.huber_loss is deprecated. Please use tf.compat.v1.losses.huber_loss instead.
#
# W1210 09:24:29.317742 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/core/losses.py:177: The name tf.losses.huber_loss is deprecated. Please use tf.compat.v1.losses.huber_loss instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/losses.py:183: The name tf.losses.Reduction is deprecated. Please use tf.compat.v1.losses.Reduction instead.
#
# W1210 09:24:29.318909 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/core/losses.py:183: The name tf.losses.Reduction is deprecated. Please use tf.compat.v1.losses.Reduction instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/losses.py:350: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W1210 09:24:29.359983 140533543180160 deprecation.py:323] From /content/models/research/object_detection/core/losses.py:350: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2710: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W1210 09:24:29.550552 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2710: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:380: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# W1210 09:24:29.551457 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:380: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/builders/optimizer_builder.py:58: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# W1210 09:24:29.558626 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/builders/optimizer_builder.py:58: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:398: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W1210 09:24:29.558837 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:398: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:408: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W1210 09:24:29.559003 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:408: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:515: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W1210 09:24:32.501725 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:515: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:519: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# W1210 09:24:32.885288 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:519: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:520: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W1210 09:24:32.885529 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:520: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# INFO:tensorflow:Done calling model_fn.
# I1210 09:24:32.885782 140533543180160 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# I1210 09:24:32.886879 140533543180160 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# I1210 09:24:34.642148 140533543180160 monitored_session.py:240] Graph was finalized.
# 2019-12-10 09:24:34.642522: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2019-12-10 09:24:34.647142: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000179999 Hz
# 2019-12-10 09:24:34.647329: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xf9d72c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-12-10 09:24:34.647358: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2019-12-10 09:24:34.649296: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-10 09:24:34.733937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:24:34.734531: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xf9d7100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2019-12-10 09:24:34.734559: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2019-12-10 09:24:34.734818: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:24:34.735233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-12-10 09:24:34.735541: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-10 09:24:34.737124: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-10 09:24:34.738729: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-10 09:24:34.739062: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-10 09:24:34.740696: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-10 09:24:34.741352: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-10 09:24:34.744850: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-10 09:24:34.744962: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:24:34.745424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:24:34.745852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-10 09:24:34.745906: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-10 09:24:34.746988: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-10 09:24:34.747011: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-10 09:24:34.747021: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-10 09:24:34.747207: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:24:34.747668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:24:34.748077: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-12-10 09:24:34.748112: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10574 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Running local_init_op.
# I1210 09:24:37.481928 140533543180160 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1210 09:24:37.652566 140533543180160 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /content/drive/My Drive/datalab/trained/model.ckpt.
# I1210 09:24:42.613878 140533543180160 basic_session_run_hooks.py:606] Saving checkpoints for 0 into /content/drive/My Drive/datalab/trained/model.ckpt.
# 2019-12-10 09:24:47.274290: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-10 09:24:47.964815: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# INFO:tensorflow:loss = 1.4830741, step = 0
# I1210 09:24:50.268840 140533543180160 basic_session_run_hooks.py:262] loss = 1.4830741, step = 0
# INFO:tensorflow:global_step/sec: 2.93028
# I1210 09:25:24.394343 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 2.93028
# INFO:tensorflow:loss = 0.15221071, step = 100 (34.126 sec)
# I1210 09:25:24.395251 140533543180160 basic_session_run_hooks.py:260] loss = 0.15221071, step = 100 (34.126 sec)
# INFO:tensorflow:global_step/sec: 4.36662
# I1210 09:25:47.295360 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 4.36662
# INFO:tensorflow:loss = 0.49931535, step = 200 (22.901 sec)
# I1210 09:25:47.296238 140533543180160 basic_session_run_hooks.py:260] loss = 0.49931535, step = 200 (22.901 sec)
# INFO:tensorflow:global_step/sec: 6.34785
# I1210 09:26:03.048804 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 6.34785
# INFO:tensorflow:loss = 0.14200702, step = 300 (15.754 sec)
# I1210 09:26:03.049788 140533543180160 basic_session_run_hooks.py:260] loss = 0.14200702, step = 300 (15.754 sec)
# INFO:tensorflow:global_step/sec: 7.37504
# I1210 09:26:16.607976 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 7.37504
# INFO:tensorflow:loss = 0.12536472, step = 400 (13.559 sec)
# I1210 09:26:16.608918 140533543180160 basic_session_run_hooks.py:260] loss = 0.12536472, step = 400 (13.559 sec)
# INFO:tensorflow:global_step/sec: 6.54523
# I1210 09:26:31.886284 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 6.54523
# INFO:tensorflow:loss = 0.9335635, step = 500 (15.278 sec)
# I1210 09:26:31.887172 140533543180160 basic_session_run_hooks.py:260] loss = 0.9335635, step = 500 (15.278 sec)
# INFO:tensorflow:global_step/sec: 7.76623
# I1210 09:26:44.762504 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 7.76623
# INFO:tensorflow:loss = 0.47959393, step = 600 (12.877 sec)
# I1210 09:26:44.763989 140533543180160 basic_session_run_hooks.py:260] loss = 0.47959393, step = 600 (12.877 sec)
# INFO:tensorflow:global_step/sec: 8.57284
# I1210 09:26:56.427283 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 8.57284
# INFO:tensorflow:loss = 0.20988704, step = 700 (11.664 sec)
# I1210 09:26:56.428356 140533543180160 basic_session_run_hooks.py:260] loss = 0.20988704, step = 700 (11.664 sec)
# INFO:tensorflow:global_step/sec: 8.13692
# I1210 09:27:08.716996 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 8.13692
# INFO:tensorflow:loss = 0.18749385, step = 800 (12.290 sec)
# I1210 09:27:08.717921 140533543180160 basic_session_run_hooks.py:260] loss = 0.18749385, step = 800 (12.290 sec)
# INFO:tensorflow:global_step/sec: 9.09263
# I1210 09:27:19.714834 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.09263
# INFO:tensorflow:loss = 0.49992692, step = 900 (10.998 sec)
# I1210 09:27:19.715868 140533543180160 basic_session_run_hooks.py:260] loss = 0.49992692, step = 900 (10.998 sec)
# INFO:tensorflow:global_step/sec: 8.6192
# I1210 09:27:31.316832 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 8.6192
# INFO:tensorflow:loss = 0.113407716, step = 1000 (11.602 sec)
# I1210 09:27:31.317692 140533543180160 basic_session_run_hooks.py:260] loss = 0.113407716, step = 1000 (11.602 sec)
# INFO:tensorflow:global_step/sec: 8.08203
# I1210 09:27:43.689975 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 8.08203
# INFO:tensorflow:loss = 0.2555935, step = 1100 (12.373 sec)
# I1210 09:27:43.691040 140533543180160 basic_session_run_hooks.py:260] loss = 0.2555935, step = 1100 (12.373 sec)
# INFO:tensorflow:global_step/sec: 8.8468
# I1210 09:27:54.993502 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 8.8468
# INFO:tensorflow:loss = 0.18372974, step = 1200 (11.303 sec)
# I1210 09:27:54.994498 140533543180160 basic_session_run_hooks.py:260] loss = 0.18372974, step = 1200 (11.303 sec)
# INFO:tensorflow:global_step/sec: 9.84665
# I1210 09:28:05.149235 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.84665
# INFO:tensorflow:loss = 0.6476123, step = 1300 (10.156 sec)
# I1210 09:28:05.150315 140533543180160 basic_session_run_hooks.py:260] loss = 0.6476123, step = 1300 (10.156 sec)
# INFO:tensorflow:global_step/sec: 8.38117
# I1210 09:28:17.080755 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 8.38117
# INFO:tensorflow:loss = 0.07348513, step = 1400 (11.931 sec)
# I1210 09:28:17.081780 140533543180160 basic_session_run_hooks.py:260] loss = 0.07348513, step = 1400 (11.931 sec)
# INFO:tensorflow:global_step/sec: 8.3349
# I1210 09:28:29.078454 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 8.3349
# INFO:tensorflow:loss = 0.172335, step = 1500 (11.998 sec)
# I1210 09:28:29.079422 140533543180160 basic_session_run_hooks.py:260] loss = 0.172335, step = 1500 (11.998 sec)
# INFO:tensorflow:global_step/sec: 9.42561
# I1210 09:28:39.687884 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.42561
# INFO:tensorflow:loss = 0.1893143, step = 1600 (10.610 sec)
# I1210 09:28:39.689047 140533543180160 basic_session_run_hooks.py:260] loss = 0.1893143, step = 1600 (10.610 sec)
# INFO:tensorflow:global_step/sec: 9.8294
# I1210 09:28:49.861425 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.8294
# INFO:tensorflow:loss = 0.36024743, step = 1700 (10.174 sec)
# I1210 09:28:49.862713 140533543180160 basic_session_run_hooks.py:260] loss = 0.36024743, step = 1700 (10.174 sec)
# INFO:tensorflow:global_step/sec: 9.2558
# I1210 09:29:00.665464 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.2558
# INFO:tensorflow:loss = 0.243248, step = 1800 (10.804 sec)
# I1210 09:29:00.666344 140533543180160 basic_session_run_hooks.py:260] loss = 0.243248, step = 1800 (10.804 sec)
# INFO:tensorflow:global_step/sec: 8.88954
# I1210 09:29:11.914655 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 8.88954
# INFO:tensorflow:loss = 0.3780037, step = 1900 (11.249 sec)
# I1210 09:29:11.915656 140533543180160 basic_session_run_hooks.py:260] loss = 0.3780037, step = 1900 (11.249 sec)
# INFO:tensorflow:global_step/sec: 9.64688
# I1210 09:29:22.280725 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.64688
# INFO:tensorflow:loss = 0.2328367, step = 2000 (10.366 sec)
# I1210 09:29:22.281812 140533543180160 basic_session_run_hooks.py:260] loss = 0.2328367, step = 2000 (10.366 sec)
# INFO:tensorflow:global_step/sec: 10.01
# I1210 09:29:32.270682 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.01
# INFO:tensorflow:loss = 0.22974166, step = 2100 (9.990 sec)
# I1210 09:29:32.271487 140533543180160 basic_session_run_hooks.py:260] loss = 0.22974166, step = 2100 (9.990 sec)
# INFO:tensorflow:global_step/sec: 9.61702
# I1210 09:29:42.668901 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.61702
# INFO:tensorflow:loss = 0.41033855, step = 2200 (10.398 sec)
# I1210 09:29:42.669828 140533543180160 basic_session_run_hooks.py:260] loss = 0.41033855, step = 2200 (10.398 sec)
# INFO:tensorflow:global_step/sec: 8.88215
# I1210 09:29:53.927455 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 8.88215
# INFO:tensorflow:loss = 0.38235962, step = 2300 (11.259 sec)
# I1210 09:29:53.928383 140533543180160 basic_session_run_hooks.py:260] loss = 0.38235962, step = 2300 (11.259 sec)
# INFO:tensorflow:global_step/sec: 9.64272
# I1210 09:30:04.297990 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.64272
# INFO:tensorflow:loss = 1.4544754, step = 2400 (10.371 sec)
# I1210 09:30:04.299007 140533543180160 basic_session_run_hooks.py:260] loss = 1.4544754, step = 2400 (10.371 sec)
# INFO:tensorflow:global_step/sec: 10.0005
# I1210 09:30:14.297494 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.0005
# INFO:tensorflow:loss = 0.11595913, step = 2500 (10.000 sec)
# I1210 09:30:14.298854 140533543180160 basic_session_run_hooks.py:260] loss = 0.11595913, step = 2500 (10.000 sec)
# INFO:tensorflow:global_step/sec: 10.0384
# I1210 09:30:24.259212 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.0384
# INFO:tensorflow:loss = 0.3478639, step = 2600 (9.961 sec)
# I1210 09:30:24.260131 140533543180160 basic_session_run_hooks.py:260] loss = 0.3478639, step = 2600 (9.961 sec)
# INFO:tensorflow:global_step/sec: 10.0535
# I1210 09:30:34.206039 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.0535
# INFO:tensorflow:loss = 0.5757303, step = 2700 (9.947 sec)
# I1210 09:30:34.206873 140533543180160 basic_session_run_hooks.py:260] loss = 0.5757303, step = 2700 (9.947 sec)
# INFO:tensorflow:global_step/sec: 9.88541
# I1210 09:30:44.321974 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.88541
# INFO:tensorflow:loss = 0.26600638, step = 2800 (10.116 sec)
# I1210 09:30:44.322986 140533543180160 basic_session_run_hooks.py:260] loss = 0.26600638, step = 2800 (10.116 sec)
# INFO:tensorflow:global_step/sec: 10.0553
# I1210 09:30:54.266985 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.0553
# INFO:tensorflow:loss = 0.26256317, step = 2900 (9.946 sec)
# I1210 09:30:54.268664 140533543180160 basic_session_run_hooks.py:260] loss = 0.26256317, step = 2900 (9.946 sec)
# INFO:tensorflow:global_step/sec: 10.1058
# I1210 09:31:04.162302 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.1058
# INFO:tensorflow:loss = 0.44611865, step = 3000 (9.895 sec)
# I1210 09:31:04.163406 140533543180160 basic_session_run_hooks.py:260] loss = 0.44611865, step = 3000 (9.895 sec)
# INFO:tensorflow:global_step/sec: 9.63054
# I1210 09:31:14.545934 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.63054
# INFO:tensorflow:loss = 0.18598823, step = 3100 (10.383 sec)
# I1210 09:31:14.546857 140533543180160 basic_session_run_hooks.py:260] loss = 0.18598823, step = 3100 (10.383 sec)
# INFO:tensorflow:global_step/sec: 9.97855
# I1210 09:31:24.567427 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.97855
# INFO:tensorflow:loss = 0.42165384, step = 3200 (10.022 sec)
# I1210 09:31:24.568484 140533543180160 basic_session_run_hooks.py:260] loss = 0.42165384, step = 3200 (10.022 sec)
# INFO:tensorflow:global_step/sec: 10.0969
# I1210 09:31:34.471470 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.0969
# INFO:tensorflow:loss = 0.2239244, step = 3300 (9.905 sec)
# I1210 09:31:34.473342 140533543180160 basic_session_run_hooks.py:260] loss = 0.2239244, step = 3300 (9.905 sec)
# INFO:tensorflow:global_step/sec: 10.0528
# I1210 09:31:44.418977 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.0528
# INFO:tensorflow:loss = 0.21045226, step = 3400 (9.946 sec)
# I1210 09:31:44.419793 140533543180160 basic_session_run_hooks.py:260] loss = 0.21045226, step = 3400 (9.946 sec)
# INFO:tensorflow:global_step/sec: 10.009
# I1210 09:31:54.409982 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.009
# INFO:tensorflow:loss = 0.33448598, step = 3500 (9.991 sec)
# I1210 09:31:54.411024 140533543180160 basic_session_run_hooks.py:260] loss = 0.33448598, step = 3500 (9.991 sec)
# INFO:tensorflow:global_step/sec: 10.1889
# I1210 09:32:04.224554 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.1889
# INFO:tensorflow:loss = 0.2609634, step = 3600 (9.815 sec)
# I1210 09:32:04.225670 140533543180160 basic_session_run_hooks.py:260] loss = 0.2609634, step = 3600 (9.815 sec)
# INFO:tensorflow:global_step/sec: 9.90937
# I1210 09:32:14.316008 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.90937
# INFO:tensorflow:loss = 0.31463912, step = 3700 (10.091 sec)
# I1210 09:32:14.317029 140533543180160 basic_session_run_hooks.py:260] loss = 0.31463912, step = 3700 (10.091 sec)
# INFO:tensorflow:global_step/sec: 10.0633
# I1210 09:32:24.253119 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 10.0633
# INFO:tensorflow:loss = 0.09437081, step = 3800 (9.937 sec)
# I1210 09:32:24.254323 140533543180160 basic_session_run_hooks.py:260] loss = 0.09437081, step = 3800 (9.937 sec)
# INFO:tensorflow:global_step/sec: 9.93385
# I1210 09:32:34.319745 140533543180160 basic_session_run_hooks.py:692] global_step/sec: 9.93385
# INFO:tensorflow:loss = 0.4170699, step = 3900 (10.066 sec)
# I1210 09:32:34.320710 140533543180160 basic_session_run_hooks.py:260] loss = 0.4170699, step = 3900 (10.066 sec)
# INFO:tensorflow:global_step/sec: 9.89957
# ...
# I1210 09:43:44.337306 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:43:44.352267 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Done calling model_fn.
# I1210 09:43:46.282699 140533543180160 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-10T09:43:46Z
# I1210 09:43:46.298155 140533543180160 evaluation.py:255] Starting evaluation at 2019-12-10T09:43:46Z
# INFO:tensorflow:Graph was finalized.
# I1210 09:43:46.714484 140533543180160 monitored_session.py:240] Graph was finalized.
# 2019-12-10 09:43:46.715166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:43:46.715537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-12-10 09:43:46.715647: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-10 09:43:46.715682: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-10 09:43:46.715713: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-10 09:43:46.715735: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-10 09:43:46.715759: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-10 09:43:46.715778: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-10 09:43:46.715803: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-10 09:43:46.715885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:43:46.716183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:43:46.716424: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-10 09:43:46.716465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-10 09:43:46.716478: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-10 09:43:46.716488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-10 09:43:46.716574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:43:46.716884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:43:46.717140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10574 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/datalab/trained/model.ckpt-10000
# I1210 09:43:46.718996 140533543180160 saver.py:1284] Restoring parameters from /content/drive/My Drive/datalab/trained/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# I1210 09:43:47.913661 140533543180160 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1210 09:43:48.083256 140533543180160 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 486 images.
# I1210 09:44:28.116654 140531350132480 coco_evaluation.py:205] Performing evaluation on 486 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I1210 09:44:28.118217 140531350132480 coco_tools.py:115] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.11s)
# I1210 09:44:28.230266 140531350132480 coco_tools.py:137] DONE (t=0.11s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=3.24s).
# Accumulating evaluation results...
# DONE (t=0.38s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.230
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.244
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.435
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.475
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.368
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.633
# INFO:tensorflow:Finished evaluation at 2019-12-10-09:44:32
# I1210 09:44:32.073450 140533543180160 evaluation.py:275] Finished evaluation at 2019-12-10-09:44:32
# INFO:tensorflow:Saving dict for global step 10000: DetectionBoxes_Precision/mAP = 0.22974633, DetectionBoxes_Precision/mAP (large) = 0.35034764, DetectionBoxes_Precision/mAP (medium) = 0.10997416, DetectionBoxes_Precision/mAP (small) = 0.003122098, DetectionBoxes_Precision/mAP@.50IOU = 0.39471385, DetectionBoxes_Precision/mAP@.75IOU = 0.24413504, DetectionBoxes_Recall/AR@1 = 0.3059671, DetectionBoxes_Recall/AR@10 = 0.43477365, DetectionBoxes_Recall/AR@100 = 0.47530866, DetectionBoxes_Recall/AR@100 (large) = 0.6327338, DetectionBoxes_Recall/AR@100 (medium) = 0.36842105, DetectionBoxes_Recall/AR@100 (small) = 0.08133333, Loss/BoxClassifierLoss/classification_loss = 0.087438226, Loss/BoxClassifierLoss/localization_loss = 0.051367097, Loss/RPNLoss/localization_loss = 0.15295905, Loss/RPNLoss/objectness_loss = 0.14238934, Loss/total_loss = 0.43415385, global_step = 10000, learning_rate = 0.0002, loss = 0.43415385
# I1210 09:44:32.073744 140533543180160 estimator.py:2049] Saving dict for global step 10000: DetectionBoxes_Precision/mAP = 0.22974633, DetectionBoxes_Precision/mAP (large) = 0.35034764, DetectionBoxes_Precision/mAP (medium) = 0.10997416, DetectionBoxes_Precision/mAP (small) = 0.003122098, DetectionBoxes_Precision/mAP@.50IOU = 0.39471385, DetectionBoxes_Precision/mAP@.75IOU = 0.24413504, DetectionBoxes_Recall/AR@1 = 0.3059671, DetectionBoxes_Recall/AR@10 = 0.43477365, DetectionBoxes_Recall/AR@100 = 0.47530866, DetectionBoxes_Recall/AR@100 (large) = 0.6327338, DetectionBoxes_Recall/AR@100 (medium) = 0.36842105, DetectionBoxes_Recall/AR@100 (small) = 0.08133333, Loss/BoxClassifierLoss/classification_loss = 0.087438226, Loss/BoxClassifierLoss/localization_loss = 0.051367097, Loss/RPNLoss/localization_loss = 0.15295905, Loss/RPNLoss/objectness_loss = 0.14238934, Loss/total_loss = 0.43415385, global_step = 10000, learning_rate = 0.0002, loss = 0.43415385
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: /content/drive/My Drive/datalab/trained/model.ckpt-10000
# I1210 09:44:32.085990 140533543180160 estimator.py:2109] Saving 'checkpoint_path' summary for global step 10000: /content/drive/My Drive/datalab/trained/model.ckpt-10000
# INFO:tensorflow:Performing the final export in the end of training.
# I1210 09:44:32.087086 140533543180160 exporter.py:410] Performing the final export in the end of training.
# WARNING:tensorflow:From /content/models/research/object_detection/inputs.py:750: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1210 09:44:32.096362 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/inputs.py:750: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# INFO:tensorflow:Calling model_fn.
# I1210 09:44:32.322782 140533543180160 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:44:33.849635 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:44:33.861979 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1210 09:44:33.862278 140533543180160 convolutional_box_predictor.py:151] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:44:34.884078 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:44:34.898729 140533543180160 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:426: The name tf.saved_model.signature_constants.PREDICT_METHOD_NAME is deprecated. Please use tf.saved_model.PREDICT_METHOD_NAME instead.
#
# W1210 09:44:35.466464 140533543180160 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:426: The name tf.saved_model.signature_constants.PREDICT_METHOD_NAME is deprecated. Please use tf.saved_model.PREDICT_METHOD_NAME instead.
#
# INFO:tensorflow:Done calling model_fn.
# I1210 09:44:35.714308 140533543180160 estimator.py:1150] Done calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W1210 09:44:35.714564 140533543180160 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# I1210 09:44:35.715262 140533543180160 export_utils.py:170] Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# I1210 09:44:35.715372 140533543180160 export_utils.py:170] Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# I1210 09:44:35.715425 140533543180160 export_utils.py:170] Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# I1210 09:44:35.715470 140533543180160 export_utils.py:170] Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# I1210 09:44:35.715511 140533543180160 export_utils.py:170] Signatures INCLUDED in export for Eval: None
# 2019-12-10 09:44:35.716028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:44:35.716345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-12-10 09:44:35.716429: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-10 09:44:35.716445: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-10 09:44:35.716462: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-10 09:44:35.716476: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-10 09:44:35.716488: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-10 09:44:35.716503: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-10 09:44:35.716518: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-10 09:44:35.716577: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:44:35.716902: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:44:35.717142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-10 09:44:35.717178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-10 09:44:35.717187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-10 09:44:35.717195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-10 09:44:35.717263: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:44:35.717521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:44:35.717777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10574 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/datalab/trained/model.ckpt-10000
# I1210 09:44:35.721159 140533543180160 saver.py:1284] Restoring parameters from /content/drive/My Drive/datalab/trained/model.ckpt-10000
# INFO:tensorflow:Assets added to graph.
# I1210 09:44:36.313174 140533543180160 builder_impl.py:665] Assets added to graph.
# INFO:tensorflow:No assets to write.
# I1210 09:44:36.313391 140533543180160 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: /content/drive/My Drive/datalab/trained/export/Servo/temp-b'1575971072'/saved_model.pb
# I1210 09:44:37.251582 140533543180160 builder_impl.py:425] SavedModel written to: /content/drive/My Drive/datalab/trained/export/Servo/temp-b'1575971072'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.090280205.
# I1210 09:44:37.483812 140533543180160 estimator.py:371] Loss for final step: 0.090280205.

# %% [markdown]
# #Export trained model
#
# Export trained model with highest step number in filename.

# %%
# %cd /content/drive/My\ Drive/datalab

lst = os.listdir('trained')
lf = filter(lambda k: 'model.ckpt-' in k, lst)
last_model = sorted(lf)[-1].replace('.meta', '')

# !python /content/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path=/content/models/research/object_detection/samples/configs/faster_rcnn_inception_v2_pets.config \
    --output_directory=fine_tuned_model \
    --trained_checkpoint_prefix=trained/$last_model
# Out:
# /content/drive/My Drive/datalab
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:374: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/export_inference_graph.py:162: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1210 09:49:55.810818 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:402: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W1210 09:49:55.815713 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:402: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:121: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1210 09:49:55.817836 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:121: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/preprocessor.py:2689: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# W1210 09:49:55.854768 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/core/preprocessor.py:2689: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:168: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1210 09:49:55.897726 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:168: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:2784: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1210 09:49:55.906479 140578510940032 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:2784: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/models/research/object_detection/core/anchor_generator.py:171: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# W1210 09:49:57.178084 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/core/anchor_generator.py:171: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:49:57.184249 140578510940032 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:558: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# W1210 09:49:57.184580 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:558: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:49:57.197998 140578510940032 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/predictors/convolutional_box_predictor.py:150: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1210 09:49:57.198350 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/predictors/convolutional_box_predictor.py:150: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1210 09:49:57.198474 140578510940032 convolutional_box_predictor.py:151] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /content/models/research/object_detection/core/box_list_ops.py:141: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1210 09:49:57.245870 140578510940032 deprecation.py:323] From /content/models/research/object_detection/core/box_list_ops.py:141: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/models/research/object_detection/utils/spatial_transform_ops.py:419: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W1210 09:49:57.743561 140578510940032 deprecation.py:506] From /content/models/research/object_detection/utils/spatial_transform_ops.py:419: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:191: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W1210 09:49:57.759718 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:191: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W1210 09:49:58.325949 140578510940032 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:49:58.330899 140578510940032 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1210 09:49:58.348839 140578510940032 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:278: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# W1210 09:49:59.105489 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:278: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:383: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# W1210 09:49:59.105758 140578510940032 deprecation.py:323] From /content/models/research/object_detection/exporter.py:383: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:415: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1210 09:49:59.108484 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:415: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:539: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# W1210 09:49:59.108676 140578510940032 deprecation.py:323] From /content/models/research/object_detection/exporter.py:539: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# W1210 09:49:59.109574 140578510940032 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 229 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/12.84m params)
#   Conv (--/2.65m params)
#     Conv/biases (512, 512/512 params)
#     Conv/weights (3x3x576x512, 2.65m/2.65m params)
#   FirstStageBoxPredictor (--/36.94k params)
#     FirstStageBoxPredictor/BoxEncodingPredictor (--/24.62k params)
#       FirstStageBoxPredictor/BoxEncodingPredictor/biases (48, 48/48 params)
#       FirstStageBoxPredictor/BoxEncodingPredictor/weights (1x1x512x48, 24.58k/24.58k params)
#     FirstStageBoxPredictor/ClassPredictor (--/12.31k params)
#       FirstStageBoxPredictor/ClassPredictor/biases (24, 24/24 params)
#       FirstStageBoxPredictor/ClassPredictor/weights (1x1x512x24, 12.29k/12.29k params)
#   FirstStageFeatureExtractor (--/4.25m params)
#     FirstStageFeatureExtractor/InceptionV2 (--/4.25m params)
#       FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7 (--/2.71k params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm (--/0 params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/depthwise_weights (7x7x3x8, 1.18k/1.18k params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/pointwise_weights (1x1x24x64, 1.54k/1.54k params)
#       FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1 (--/4.10k params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm (--/0 params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/weights (1x1x64x64, 4.10k/4.10k params)
#       FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3 (--/110.59k params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm (--/0 params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/weights (3x3x64x192, 110.59k/110.59k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_3b (--/218.11k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0 (--/12.29k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1 (--/12.29k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/weights (1x1x192x64, 12.29k/12.29k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1 (--/49.15k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1 (--/12.29k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/weights (1x1x192x64, 12.29k/12.29k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3 (--/36.86k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/weights (3x3x64x64, 36.86k/36.86k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2 (--/150.53k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1 (--/12.29k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/weights (1x1x192x64, 12.29k/12.29k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3 (--/82.94k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/weights (3x3x96x96, 82.94k/82.94k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_3 (--/6.14k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_3/Conv2d_0b_1x1 (--/6.14k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_3/Conv2d_0b_1x1/weights (1x1x192x32, 6.14k/6.14k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_3c (--/259.07k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_0 (--/16.38k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_0/Conv2d_0a_1x1 (--/16.38k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_0/Conv2d_0a_1x1/weights (1x1x256x64, 16.38k/16.38k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1 (--/71.68k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0a_1x1 (--/16.38k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0a_1x1/weights (1x1x256x64, 16.38k/16.38k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2 (--/154.62k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0a_1x1 (--/16.38k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0a_1x1/weights (1x1x256x64, 16.38k/16.38k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0c_3x3 (--/82.94k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0c_3x3/weights (3x3x96x96, 82.94k/82.94k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_3 (--/16.38k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_3/Conv2d_0b_1x1 (--/16.38k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_3/Conv2d_0b_1x1/weights (1x1x256x64, 16.38k/16.38k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4a (--/384.00k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0 (--/225.28k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_0a_1x1 (--/40.96k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_0a_1x1/weights (1x1x320x128, 40.96k/40.96k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_1a_3x3 (--/184.32k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_1a_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_1a_3x3/weights (3x3x128x160, 184.32k/184.32k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1 (--/158.72k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0a_1x1 (--/20.48k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0a_1x1/weights (1x1x320x64, 20.48k/20.48k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_1a_3x3 (--/82.94k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_1a_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_1a_3x3/weights (3x3x96x96, 82.94k/82.94k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4b (--/608.26k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_0 (--/129.02k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_0/Conv2d_0a_1x1 (--/129.02k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_0/Conv2d_0a_1x1/weights (1x1x576x224, 129.02k/129.02k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1 (--/92.16k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0a_1x1 (--/36.86k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0a_1x1/weights (1x1x576x64, 36.86k/36.86k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2 (--/313.34k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0a_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0a_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0b_3x3 (--/110.59k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0b_3x3/weights (3x3x96x128, 110.59k/110.59k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0c_3x3 (--/147.46k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0c_3x3/weights (3x3x128x128, 147.46k/147.46k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_3 (--/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_3/Conv2d_0b_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_3/Conv2d_0b_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4c (--/663.55k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_0 (--/110.59k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_0/Conv2d_0a_1x1 (--/110.59k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_0/Conv2d_0a_1x1/weights (1x1x576x192, 110.59k/110.59k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1 (--/165.89k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0a_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0a_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0b_3x3 (--/110.59k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0b_3x3/weights (3x3x96x128, 110.59k/110.59k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2 (--/313.34k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0a_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0a_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0b_3x3 (--/110.59k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0b_3x3/weights (3x3x96x128, 110.59k/110.59k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0c_3x3 (--/147.46k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0c_3x3/weights (3x3x128x128, 147.46k/147.46k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_3 (--/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_3/Conv2d_0b_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_3/Conv2d_0b_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4d (--/893.95k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_0 (--/92.16k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_0/Conv2d_0a_1x1 (--/92.16k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_0/Conv2d_0a_1x1/weights (1x1x576x160, 92.16k/92.16k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1 (--/258.05k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0a_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0a_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0b_3x3 (--/184.32k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0b_3x3/weights (3x3x128x160, 184.32k/184.32k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2 (--/488.45k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0a_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0a_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0b_3x3 (--/184.32k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0b_3x3/weights (3x3x128x160, 184.32k/184.32k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0c_3x3 (--/230.40k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0c_3x3/weights (3x3x160x160, 230.40k/230.40k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_3 (--/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_3/Conv2d_0b_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_3/Conv2d_0b_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4e (--/1.11m params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_0 (--/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_0/Conv2d_0a_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_0/Conv2d_0a_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1 (--/294.91k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0a_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0a_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0b_3x3 (--/221.18k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0b_3x3/weights (3x3x128x192, 221.18k/221.18k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2 (--/700.42k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0a_1x1 (--/92.16k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0a_1x1/weights (1x1x576x160, 92.16k/92.16k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0b_3x3 (--/276.48k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0b_3x3/weights (3x3x160x192, 276.48k/276.48k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0c_3x3 (--/331.78k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0c_3x3/weights (3x3x192x192, 331.78k/331.78k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_3 (--/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_3/Conv2d_0b_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_3/Conv2d_0b_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#   SecondStageBoxPredictor (--/6.15k params)
#     SecondStageBoxPredictor/BoxEncodingPredictor (--/4.10k params)
#       SecondStageBoxPredictor/BoxEncodingPredictor/biases (4, 4/4 params)
#       SecondStageBoxPredictor/BoxEncodingPredictor/weights (1024x4, 4.10k/4.10k params)
#     SecondStageBoxPredictor/ClassPredictor (--/2.05k params)
#       SecondStageBoxPredictor/ClassPredictor/biases (2, 2/2 params)
#       SecondStageBoxPredictor/ClassPredictor/weights (1024x2, 2.05k/2.05k params)
#   SecondStageFeatureExtractor (--/5.89m params)
#     SecondStageFeatureExtractor/InceptionV2 (--/5.89m params)
#       SecondStageFeatureExtractor/InceptionV2/Mixed_5a (--/1.44m params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0 (--/294.91k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_0a_1x1 (--/73.73k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_0a_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_1a_3x3 (--/221.18k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_1a_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_1a_3x3/weights (3x3x128x192, 221.18k/221.18k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1 (--/1.14m params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0a_1x1 (--/110.59k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0a_1x1/weights (1x1x576x192, 110.59k/110.59k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0b_3x3 (--/442.37k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0b_3x3/weights (3x3x192x256, 442.37k/442.37k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_1a_3x3 (--/589.82k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_1a_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_1a_3x3/weights (3x3x256x256, 589.82k/589.82k params)
#       SecondStageFeatureExtractor/InceptionV2/Mixed_5b (--/2.18m params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_0 (--/360.45k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_0/Conv2d_0a_1x1 (--/360.45k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_0/Conv2d_0a_1x1/weights (1x1x1024x352, 360.45k/360.45k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1 (--/749.57k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0a_1x1 (--/196.61k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0a_1x1/weights (1x1x1024x192, 196.61k/196.61k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0b_3x3 (--/552.96k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0b_3x3/weights (3x3x192x320, 552.96k/552.96k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2 (--/937.98k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0a_1x1 (--/163.84k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0a_1x1/weights (1x1x1024x160, 163.84k/163.84k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0b_3x3 (--/322.56k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0b_3x3/weights (3x3x160x224, 322.56k/322.56k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0c_3x3 (--/451.58k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0c_3x3/weights (3x3x224x224, 451.58k/451.58k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_3 (--/131.07k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_3/Conv2d_0b_1x1 (--/131.07k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_3/Conv2d_0b_1x1/weights (1x1x1024x128, 131.07k/131.07k params)
#       SecondStageFeatureExtractor/InceptionV2/Mixed_5c (--/2.28m params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_0 (--/360.45k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_0/Conv2d_0a_1x1 (--/360.45k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_0/Conv2d_0a_1x1/weights (1x1x1024x352, 360.45k/360.45k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1 (--/749.57k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0a_1x1 (--/196.61k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0a_1x1/weights (1x1x1024x192, 196.61k/196.61k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0b_3x3 (--/552.96k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0b_3x3/weights (3x3x192x320, 552.96k/552.96k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2 (--/1.04m params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0a_1x1 (--/196.61k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0a_1x1/weights (1x1x1024x192, 196.61k/196.61k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0b_3x3 (--/387.07k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0b_3x3/weights (3x3x192x224, 387.07k/387.07k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0c_3x3 (--/451.58k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0c_3x3/weights (3x3x224x224, 451.58k/451.58k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_3 (--/131.07k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_3/Conv2d_0b_1x1 (--/131.07k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_3/Conv2d_0b_1x1/weights (1x1x1024x128, 131.07k/131.07k params)
#
# ======================End of Report==========================
# 229 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*,.*Initializer.*,.*Regularizer.*,.*BiasAdd.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.16k flops)
#   map/while/ToNormalizedCoordinates/Scale/mul_1 (300/300 flops)
#   SecondStagePostprocessor/map/while/ClipToWindow/Maximum_3 (300/300 flops)
#   SecondStagePostprocessor/map/while/ClipToWindow/Minimum (300/300 flops)
#   SecondStagePostprocessor/map/while/ClipToWindow/Minimum_1 (300/300 flops)
#   SecondStagePostprocessor/map/while/ClipToWindow/Minimum_2 (300/300 flops)
#   SecondStagePostprocessor/map/while/ClipToWindow/Minimum_3 (300/300 flops)
#   SecondStagePostprocessor/map/while/ClipToWindow/Maximum_2 (300/300 flops)
#   SecondStagePostprocessor/map/while/ClipToWindow/Maximum_1 (300/300 flops)
#   SecondStagePostprocessor/map/while/ToNormalizedCoordinates/Scale/mul (300/300 flops)
#   SecondStagePostprocessor/map/while/ToNormalizedCoordinates/Scale/mul_1 (300/300 flops)
#   SecondStagePostprocessor/map/while/ToNormalizedCoordinates/Scale/mul_2 (300/300 flops)
#   SecondStagePostprocessor/map/while/ToNormalizedCoordinates/Scale/mul_3 (300/300 flops)
#   SecondStagePostprocessor/map/while/ClipToWindow/Maximum (300/300 flops)
#   map/while/ToNormalizedCoordinates/Scale/mul (300/300 flops)
#   map/while/ToNormalizedCoordinates/Scale/mul_2 (300/300 flops)
#   map_2/while/mul_3 (300/300 flops)
#   map_2/while/mul_2 (300/300 flops)
#   map_2/while/mul_1 (300/300 flops)
#   map_2/while/mul (300/300 flops)
#   map/while/ToNormalizedCoordinates/Scale/mul_3 (300/300 flops)
#   GridAnchorGenerator/mul (12/12 flops)
#   GridAnchorGenerator/mul_1 (12/12 flops)
#   GridAnchorGenerator/mul_2 (12/12 flops)
#   GridAnchorGenerator/truediv (12/12 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_15 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_9 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_17 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_16 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_11 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_12 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_13 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_14 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_18 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_10 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_9 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_8 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_7 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_6 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_5 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_4 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_3 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_2 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub (1/1 flops)
#   SecondStagePostprocessor/map/while/ToNormalizedCoordinates/truediv_1 (1/1 flops)
#   mul (1/1 flops)
#   map_2/while/Less_1 (1/1 flops)
#   map_2/while/Less (1/1 flops)
#   map_1/while/ToNormalizedCoordinates/truediv_1 (1/1 flops)
#   map_1/while/ToNormalizedCoordinates/truediv (1/1 flops)
#   map_1/while/Less_1 (1/1 flops)
#   map_1/while/Less (1/1 flops)
#   map/while/ToNormalizedCoordinates/truediv_1 (1/1 flops)
#   map/while/ToNormalizedCoordinates/truediv (1/1 flops)
#   map/while/Less_1 (1/1 flops)
#   map/while/Less (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_19 (1/1 flops)
#   SecondStagePostprocessor/map/while/ToNormalizedCoordinates/truediv (1/1 flops)
#   SecondStagePostprocessor/map/while/Less_1 (1/1 flops)
#   SecondStagePostprocessor/map/while/Less (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_8 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_7 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_6 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_5 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_4 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_3 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_2 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_16 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_1 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_10 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_11 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_12 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_13 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_14 (1/1 flops)
# ...
# 2019-12-10 09:50:01.199238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-10 09:50:01.199252: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-10 09:50:01.199264: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-10 09:50:01.199277: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-10 09:50:01.199288: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-10 09:50:01.199302: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-10 09:50:01.199348: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:01.199807: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:01.200194: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-10 09:50:01.200244: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-10 09:50:01.201285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-10 09:50:01.201310: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-10 09:50:01.201320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-10 09:50:01.201411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:01.201880: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:01.202281: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-12-10 09:50:01.202311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10574 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from trained/model.ckpt-5207
# I1210 09:50:01.204774 140578510940032 saver.py:1284] Restoring parameters from trained/model.ckpt-5207
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W1210 09:50:03.081440 140578510940032 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2019-12-10 09:50:03.735420: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:03.735940: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-12-10 09:50:03.736024: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-10 09:50:03.736049: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-10 09:50:03.736066: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-10 09:50:03.736085: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-10 09:50:03.736109: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-10 09:50:03.736128: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-10 09:50:03.736147: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-10 09:50:03.736225: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:03.736683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:03.737079: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-10 09:50:03.737119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-10 09:50:03.737133: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-10 09:50:03.737142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-10 09:50:03.737229: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:03.737681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:03.738101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10574 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from trained/model.ckpt-5207
# I1210 09:50:03.740267 140578510940032 saver.py:1284] Restoring parameters from trained/model.ckpt-5207
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W1210 09:50:04.502191 140578510940032 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W1210 09:50:04.502425 140578510940032 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 356 variables.
# I1210 09:50:04.876997 140578510940032 graph_util_impl.py:334] Froze 356 variables.
# INFO:tensorflow:Converted 356 variables to const ops.
# I1210 09:50:04.986768 140578510940032 graph_util_impl.py:394] Converted 356 variables to const ops.
# 2019-12-10 09:50:05.296020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:05.296524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-12-10 09:50:05.296591: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2019-12-10 09:50:05.296607: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2019-12-10 09:50:05.296648: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2019-12-10 09:50:05.296670: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2019-12-10 09:50:05.296686: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2019-12-10 09:50:05.296698: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2019-12-10 09:50:05.296711: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-12-10 09:50:05.296781: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:05.297203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:05.297586: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-12-10 09:50:05.297632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-12-10 09:50:05.297643: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-12-10 09:50:05.297652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-12-10 09:50:05.297729: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:05.298138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-10 09:50:05.298532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10574 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:306: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
#
# W1210 09:50:05.693550 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:306: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:309: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W1210 09:50:05.695501 140578510940032 deprecation.py:323] From /content/models/research/object_detection/exporter.py:309: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:315: The name tf.saved_model.signature_def_utils.build_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.build_signature_def instead.
#
# W1210 09:50:05.695989 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:315: The name tf.saved_model.signature_def_utils.build_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.build_signature_def instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:318: The name tf.saved_model.signature_constants.PREDICT_METHOD_NAME is deprecated. Please use tf.saved_model.PREDICT_METHOD_NAME instead.
#
# W1210 09:50:05.696144 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:318: The name tf.saved_model.signature_constants.PREDICT_METHOD_NAME is deprecated. Please use tf.saved_model.PREDICT_METHOD_NAME instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:323: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
#
# W1210 09:50:05.696323 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:323: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:325: The name tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY is deprecated. Please use tf.saved_model.DEFAULT_SERVING_SIGNATURE_DEF_KEY instead.
#
# W1210 09:50:05.696418 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:325: The name tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY is deprecated. Please use tf.saved_model.DEFAULT_SERVING_SIGNATURE_DEF_KEY instead.
#
# INFO:tensorflow:No assets to save.
# I1210 09:50:05.696670 140578510940032 builder_impl.py:640] No assets to save.
# INFO:tensorflow:No assets to write.
# I1210 09:50:05.696754 140578510940032 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: fine_tuned_model/saved_model/saved_model.pb
# I1210 09:50:06.129477 140578510940032 builder_impl.py:425] SavedModel written to: fine_tuned_model/saved_model/saved_model.pb
# WARNING:tensorflow:From /content/models/research/object_detection/utils/config_util.py:188: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1210 09:50:06.164290 140578510940032 module_wrapper.py:139] From /content/models/research/object_detection/utils/config_util.py:188: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# INFO:tensorflow:Writing pipeline config file to fine_tuned_model/pipeline.config
# I1210 09:50:06.164522 140578510940032 config_util.py:190] Writing pipeline config file to fine_tuned_model/pipeline.config

# %% [markdown]
# #Upload jpg image for inference

# %%
# %cd /datalab

from google.colab import files
from os import path

uploaded = files.upload()

for name, data in uploaded.items():
  with open('image1.jpg', 'wb') as f:
    f.write(data)
    f.close()
    print('saved file ' + name)
# Out:
# /datalab
#      <input type="file" id="files-00edea41-8262-4265-b436-06b38c741855" name="files[]" multiple disabled />
#      <output id="result-00edea41-8262-4265-b436-06b38c741855">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving banana6.jpg to banana6 (3).jpg
# saved file banana6.jpg

# %% [markdown]
# # Run inference

# %%
# %cd /content/models/research/object_detection




import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops

# if tf.__version__ < '1.4.0':
#   raise ImportError('Please upgrade your tensorflow installation to v1.4.* or later!')
  

  
  
# This is needed to display the images.
# %matplotlib inline




from utils import label_map_util

from utils import visualization_utils as vis_util




# What model to download.
# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = '/content/drive/My Drive/datalab/fine_tuned_model' + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('/datalab', 'label_map.pbtxt')

NUM_CLASSES = 1




detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.GraphDef()
  with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')
    
    
    
    
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)




def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)




# If you want to test the code with your images, just add path to the images to the TEST_IMAGE_PATHS.
PATH_TO_TEST_IMAGES_DIR = '/datalab/'
TEST_IMAGE_PATHS = [ os.path.join(PATH_TO_TEST_IMAGES_DIR, 'image{}.jpg'.format(i)) for i in range(1, 2) ]

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)




def run_inference_for_single_image(image, graph):
  with graph.as_default():
    with tf.Session() as sess:
      # Get handles to input and output tensors
      ops = tf.get_default_graph().get_operations()
      all_tensor_names = {output.name for op in ops for output in op.outputs}
      tensor_dict = {}
      for key in [
          'num_detections', 'detection_boxes', 'detection_scores',
          'detection_classes', 'detection_masks'
      ]:
        tensor_name = key + ':0'
        if tensor_name in all_tensor_names:
          tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
              tensor_name)
      if 'detection_masks' in tensor_dict:
        # The following processing is only for single image
        detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
        detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
        # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
        real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
        detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
        detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
        detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
            detection_masks, detection_boxes, image.shape[0], image.shape[1])
        detection_masks_reframed = tf.cast(
            tf.greater(detection_masks_reframed, 0.5), tf.uint8)
        # Follow the convention by adding back the batch dimension
        tensor_dict['detection_masks'] = tf.expand_dims(
            detection_masks_reframed, 0)
      image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

      # Run inference
      output_dict = sess.run(tensor_dict,
                             feed_dict={image_tensor: np.expand_dims(image, 0)})

      # all outputs are float32 numpy arrays, so convert types as appropriate
      output_dict['num_detections'] = int(output_dict['num_detections'][0])
      output_dict['detection_classes'] = output_dict[
          'detection_classes'][0].astype(np.uint8)
      output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
      output_dict['detection_scores'] = output_dict['detection_scores'][0]
      if 'detection_masks' in output_dict:
        output_dict['detection_masks'] = output_dict['detection_masks'][0]
  return output_dict




for image_path in TEST_IMAGE_PATHS:
  image = Image.open(image_path)
  # the array based representation of the image will be used later in order to prepare the
  # result image with boxes and labels on it.
  image_np = load_image_into_numpy_array(image)
  # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
  image_np_expanded = np.expand_dims(image_np, axis=0)
  # Actual detection.
  output_dict = run_inference_for_single_image(image_np, detection_graph)
  # Visualization of the results of a detection.
  vis_util.visualize_boxes_and_labels_on_image_array(
      image_np,
      output_dict['detection_boxes'],
      output_dict['detection_classes'],
      output_dict['detection_scores'],
      category_index,
      instance_masks=output_dict.get('detection_masks'),
      use_normalized_coordinates=True,
      line_thickness=8)
  plt.figure(figsize=IMAGE_SIZE)
  plt.imshow(image_np)
# Out:
# /content/models/research/object_detection

# %%
# !zip -r /content/datalab.zip /content/datalab
# Out:
#   adding: content/datalab/ (stored 0%)
#   adding: content/datalab/trained/ (stored 0%)
#   adding: content/datalab/trained/graph.pbtxt (deflated 97%)
#   adding: content/datalab/trained/model.ckpt-3000.data-00000-of-00001 (deflated 6%)
#   adding: content/datalab/trained/model.ckpt-1616.meta (deflated 94%)
#   adding: content/datalab/trained/model.ckpt-1616.data-00000-of-00001 (deflated 6%)
#   adding: content/datalab/trained/model.ckpt-3000.index (deflated 72%)
#   adding: content/datalab/trained/model.ckpt-1616.index (deflated 72%)
#   adding: content/datalab/trained/checkpoint (deflated 65%)
#   adding: content/datalab/trained/model.ckpt-0.data-00000-of-00001 (deflated 53%)
#   adding: content/datalab/trained/model.ckpt-3000.meta (deflated 94%)
#   adding: content/datalab/trained/export/ (stored 0%)
#   adding: content/datalab/trained/export/Servo/ (stored 0%)
#   adding: content/datalab/trained/export/Servo/1575324862/ (stored 0%)
#   adding: content/datalab/trained/export/Servo/1575324862/variables/ (stored 0%)
#   adding: content/datalab/trained/export/Servo/1575324862/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/datalab/trained/export/Servo/1575324862/variables/variables.index (deflated 70%)
#   adding: content/datalab/trained/export/Servo/1575324862/saved_model.pb (deflated 94%)
#   adding: content/datalab/trained/eval_0/ (stored 0%)
#   adding: content/datalab/trained/eval_0/events.out.tfevents.1575324427.502454c59abc (deflated 37%)
#   adding: content/datalab/trained/model.ckpt-0.index (deflated 75%)
#   adding: content/datalab/trained/events.out.tfevents.1575323766.502454c59abc (deflated 94%)
#   adding: content/datalab/trained/model.ckpt-0.meta (deflated 94%)
#   adding: content/datalab/fine_tuned_model/ (stored 0%)
#   adding: content/datalab/fine_tuned_model/model.ckpt.meta (deflated 94%)
#   adding: content/datalab/fine_tuned_model/model.ckpt.index (deflated 70%)
#   adding: content/datalab/fine_tuned_model/checkpoint (deflated 42%)
#   adding: content/datalab/fine_tuned_model/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: content/datalab/fine_tuned_model/saved_model/ (stored 0%)
#   adding: content/datalab/fine_tuned_model/saved_model/variables/ (stored 0%)
#   adding: content/datalab/fine_tuned_model/saved_model/saved_model.pb (deflated 8%)
#   adding: content/datalab/fine_tuned_model/pipeline.config (deflated 67%)
#   adding: content/datalab/fine_tuned_model/frozen_inference_graph.pb (deflated 8%)

# %%
# !zip -r /content/models.zip /content/models
# Out:
#   adding: content/models/ (stored 0%)
#   adding: content/models/AUTHORS (deflated 34%)
#   adding: content/models/.git/ (stored 0%)
#   adding: content/models/.git/info/ (stored 0%)
#   adding: content/models/.git/info/exclude (deflated 28%)
#   adding: content/models/.git/refs/ (stored 0%)
#   adding: content/models/.git/refs/remotes/ (stored 0%)
#   adding: content/models/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/models/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/models/.git/refs/tags/ (stored 0%)
#   adding: content/models/.git/refs/heads/ (stored 0%)
#   adding: content/models/.git/refs/heads/master (stored 0%)
#   adding: content/models/.git/description (deflated 14%)
#   adding: content/models/.git/branches/ (stored 0%)
#   adding: content/models/.git/objects/ (stored 0%)
#   adding: content/models/.git/objects/info/ (stored 0%)
#   adding: content/models/.git/objects/pack/ (stored 0%)
#   adding: content/models/.git/objects/pack/pack-bfc05d9392daca8b0cbdd1650da6391e3cad3767.pack (deflated 0%)
#   adding: content/models/.git/objects/pack/pack-bfc05d9392daca8b0cbdd1650da6391e3cad3767.idx (deflated 1%)
#   adding: content/models/.git/index (deflated 66%)
#   adding: content/models/.git/HEAD (stored 0%)
#   adding: content/models/.git/config (deflated 34%)
#   adding: content/models/.git/hooks/ (stored 0%)
#   adding: content/models/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/models/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/models/.git/hooks/pre-commit.sample (deflated 43%)
#   adding: content/models/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/models/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/models/.git/hooks/update.sample (deflated 68%)
#   adding: content/models/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/models/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/models/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/models/.git/hooks/pre-push.sample (deflated 50%)
#   adding: content/models/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: content/models/.git/packed-refs (deflated 58%)
#   adding: content/models/.git/logs/ (stored 0%)
#   adding: content/models/.git/logs/refs/ (stored 0%)
#   adding: content/models/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/models/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/models/.git/logs/refs/remotes/origin/HEAD (deflated 29%)
#   adding: content/models/.git/logs/refs/heads/ (stored 0%)
#   adding: content/models/.git/logs/refs/heads/master (deflated 29%)
#   adding: content/models/.git/logs/HEAD (deflated 29%)
#   adding: content/models/.gitmodules (deflated 24%)
#   adding: content/models/.gitignore (deflated 45%)
#   adding: content/models/tutorials/ (stored 0%)
#   adding: content/models/tutorials/__init__.py (stored 0%)
#   adding: content/models/tutorials/image/ (stored 0%)
#   adding: content/models/tutorials/image/alexnet/ (stored 0%)
#   adding: content/models/tutorials/image/alexnet/alexnet_benchmark.py (deflated 72%)
#   adding: content/models/tutorials/image/alexnet/BUILD (deflated 45%)
#   adding: content/models/tutorials/image/alexnet/__init__.py (stored 0%)
#   adding: content/models/tutorials/image/__init__.py (stored 0%)
#   adding: content/models/tutorials/image/mnist/ (stored 0%)
#   adding: content/models/tutorials/image/mnist/convolutional.py (deflated 66%)
#   adding: content/models/tutorials/image/mnist/BUILD (deflated 57%)
#   adding: content/models/tutorials/image/mnist/__init__.py (stored 0%)
#   adding: content/models/tutorials/image/cifar10/ (stored 0%)
#   adding: content/models/tutorials/image/cifar10/cifar10_train.py (deflated 57%)
#   adding: content/models/tutorials/image/cifar10/BUILD (deflated 74%)
#   adding: content/models/tutorials/image/cifar10/cifar10_eval.py (deflated 58%)
#   adding: content/models/tutorials/image/cifar10/__init__.py (deflated 46%)
#   adding: content/models/tutorials/image/cifar10/cifar10_input_test.py (deflated 54%)
#   adding: content/models/tutorials/image/cifar10/cifar10_input.py (deflated 58%)
#   adding: content/models/tutorials/image/cifar10/README.md (deflated 38%)
#   adding: content/models/tutorials/image/cifar10/cifar10.py (deflated 69%)
#   adding: content/models/tutorials/image/cifar10/cifar10_multi_gpu_train.py (deflated 63%)
#   adding: content/models/tutorials/image/cifar10_estimator/ (stored 0%)
#   adding: content/models/tutorials/image/cifar10_estimator/__init__.py (stored 0%)
#   adding: content/models/tutorials/image/cifar10_estimator/cifar10_model.py (deflated 57%)
#   adding: content/models/tutorials/image/cifar10_estimator/model_base.py (deflated 75%)
#   adding: content/models/tutorials/image/cifar10_estimator/generate_cifar10_tfrecords.py (deflated 59%)
#   adding: content/models/tutorials/image/cifar10_estimator/README.md (deflated 80%)
#   adding: content/models/tutorials/image/cifar10_estimator/cifar10_utils.py (deflated 64%)
#   adding: content/models/tutorials/image/cifar10_estimator/cifar10.py (deflated 58%)
#   adding: content/models/tutorials/image/cifar10_estimator/cifar10_main.py (deflated 68%)
#   adding: content/models/tutorials/image/cifar10_estimator/cmle_config.yaml (deflated 36%)
#   adding: content/models/tutorials/image/imagenet/ (stored 0%)
#   adding: content/models/tutorials/image/imagenet/BUILD (deflated 48%)
#   adding: content/models/tutorials/image/imagenet/classify_image.py (deflated 64%)
#   adding: content/models/tutorials/README.md (deflated 19%)
#   adding: content/models/tutorials/rnn/ (stored 0%)
#   adding: content/models/tutorials/rnn/ptb/ (stored 0%)
#   adding: content/models/tutorials/rnn/ptb/ptb_word_lm.py (deflated 69%)
#   adding: content/models/tutorials/rnn/ptb/BUILD (deflated 67%)
#   adding: content/models/tutorials/rnn/ptb/__init__.py (deflated 46%)
#   adding: content/models/tutorials/rnn/ptb/reader.py (deflated 59%)
#   adding: content/models/tutorials/rnn/ptb/util.py (deflated 63%)
#   adding: content/models/tutorials/rnn/ptb/reader_test.py (deflated 53%)
#   adding: content/models/tutorials/rnn/BUILD (deflated 70%)
#   adding: content/models/tutorials/rnn/__init__.py (deflated 45%)
#   adding: content/models/tutorials/rnn/quickdraw/ (stored 0%)
#   adding: content/models/tutorials/rnn/quickdraw/create_dataset.py (deflated 63%)
#   adding: content/models/tutorials/rnn/quickdraw/BUILD (deflated 54%)
#   adding: content/models/tutorials/rnn/quickdraw/train_model.py (deflated 68%)
#   adding: content/models/tutorials/rnn/README.md (deflated 49%)
#   adding: content/models/tutorials/embedding/ (stored 0%)
#   adding: content/models/tutorials/embedding/word2vec_kernels.cc (deflated 70%)
#   adding: content/models/tutorials/embedding/word2vec_test.py (deflated 51%)
#   adding: content/models/tutorials/embedding/__init__.py (deflated 45%)
#   adding: content/models/tutorials/embedding/word2vec_optimized.py (deflated 66%)
#   adding: content/models/tutorials/embedding/word2vec_ops.cc (deflated 58%)
#   adding: content/models/tutorials/embedding/README.md (deflated 52%)
#   adding: content/models/tutorials/embedding/word2vec_optimized_test.py (deflated 51%)
#   adding: content/models/tutorials/embedding/word2vec.py (deflated 67%)
#   adding: content/models/LICENSE (deflated 65%)
#   adding: content/models/README.md (deflated 50%)
#   adding: content/models/WORKSPACE (stored 0%)
#   adding: content/models/official/ (stored 0%)
#   adding: content/models/official/r1/ (stored 0%)
#   adding: content/models/official/r1/__init__.py (stored 0%)
#   adding: content/models/official/r1/mnist/ (stored 0%)
#   adding: content/models/official/r1/mnist/__init__.py (stored 0%)
#   adding: content/models/official/r1/mnist/mnist_tpu.py (deflated 63%)
#   adding: content/models/official/r1/mnist/examples.npy (deflated 96%)
#   adding: content/models/official/r1/mnist/mnist.py (deflated 65%)
#   adding: content/models/official/r1/mnist/example3.png (stored 0%)
#   adding: content/models/official/r1/mnist/mnist_test.py (deflated 67%)
#   adding: content/models/official/r1/mnist/mnist_eager.py (deflated 63%)
#   adding: content/models/official/r1/mnist/README.md (deflated 51%)
#   adding: content/models/official/r1/mnist/dataset.py (deflated 62%)
#   adding: content/models/official/r1/mnist/mnist_eager_test.py (deflated 60%)
#   adding: content/models/official/r1/mnist/example5.png (deflated 0%)
#   adding: content/models/official/r1/boosted_trees/ (stored 0%)
#   adding: content/models/official/r1/boosted_trees/train_higgs.py (deflated 67%)
#   adding: content/models/official/r1/boosted_trees/__init__.py (stored 0%)
#   adding: content/models/official/r1/boosted_trees/README.md (deflated 56%)
#   adding: content/models/official/r1/boosted_trees/train_higgs_test.csv (deflated 61%)
#   adding: content/models/official/r1/boosted_trees/data_download.py (deflated 53%)
#   adding: content/models/official/r1/boosted_trees/train_higgs_test.py (deflated 66%)
#   adding: content/models/official/r1/resnet/ (stored 0%)
#   adding: content/models/official/r1/resnet/__init__.py (stored 0%)
#   adding: content/models/official/r1/resnet/resnet_run_loop.py (deflated 70%)
#   adding: content/models/official/r1/resnet/imagenet_main.py (deflated 66%)
#   adding: content/models/official/r1/resnet/estimator_benchmark.py (deflated 82%)
#   adding: content/models/official/r1/resnet/imagenet_preprocessing.py (deflated 66%)
#   adding: content/models/official/r1/resnet/cifar10_test.py (deflated 69%)
#   adding: content/models/official/r1/resnet/README.md (deflated 66%)
#   adding: content/models/official/r1/resnet/cifar10_download_and_extract.py (deflated 50%)
#   adding: content/models/official/r1/resnet/resnet_model.py (deflated 77%)
#   adding: content/models/official/r1/resnet/imagenet_test.py (deflated 80%)
#   adding: content/models/official/r1/resnet/layer_test.py (deflated 70%)
#   adding: content/models/official/r1/resnet/cifar10_main.py (deflated 63%)
#   adding: content/models/official/r1/wide_deep/ (stored 0%)
#   adding: content/models/official/r1/wide_deep/movielens_dataset.py (deflated 65%)
#   adding: content/models/official/r1/wide_deep/__init__.py (stored 0%)
#   adding: content/models/official/r1/wide_deep/census_test.py (deflated 66%)
#   adding: content/models/official/r1/wide_deep/movielens_test.py (deflated 57%)
#   adding: content/models/official/r1/wide_deep/census_main.py (deflated 63%)
#   adding: content/models/official/r1/wide_deep/README.md (deflated 58%)
#   adding: content/models/official/r1/wide_deep/census_dataset.py (deflated 62%)
#   adding: content/models/official/r1/wide_deep/census_test.csv (deflated 72%)
#   adding: content/models/official/r1/wide_deep/wide_deep_run_loop.py (deflated 62%)
#   adding: content/models/official/r1/wide_deep/movielens_main.py (deflated 60%)
#   adding: content/models/official/r1/utils/ (stored 0%)
#   adding: content/models/official/r1/utils/tpu_test.py (deflated 69%)
#   adding: content/models/official/r1/utils/__init__.py (stored 0%)
#   adding: content/models/official/r1/utils/tpu.py (deflated 57%)
#   adding: content/models/official/r1/utils/data/ (stored 0%)
#   adding: content/models/official/r1/utils/data/file_io.py (deflated 61%)
#   adding: content/models/official/r1/utils/data/__init__.py (stored 0%)
#   adding: content/models/official/r1/utils/data/file_io_test.py (deflated 64%)
#   adding: content/models/official/r1/utils/export.py (deflated 53%)
#   adding: content/models/official/r1/utils/export_test.py (deflated 66%)
#   adding: content/models/official/__init__.py (stored 0%)
#   adding: content/models/official/pip_package/ (stored 0%)
#   adding: content/models/official/pip_package/setup.py (deflated 51%)
#   adding: content/models/official/nlp/ (stored 0%)
#   adding: content/models/official/nlp/xlnet/ (stored 0%)
#   adding: content/models/official/nlp/xlnet/xlnet_modeling.py (deflated 80%)
#   adding: content/models/official/nlp/xlnet/run_classifier.py (deflated 66%)
#   adding: content/models/official/nlp/xlnet/run_squad.py (deflated 71%)
#   adding: content/models/official/nlp/xlnet/__init__.py (stored 0%)
#   adding: content/models/official/nlp/xlnet/classifier_utils.py (deflated 64%)
#   adding: content/models/official/nlp/xlnet/squad_utils.py (deflated 73%)
#   adding: content/models/official/nlp/xlnet/run_pretrain.py (deflated 66%)
#   adding: content/models/official/nlp/xlnet/xlnet_modeling_test.py (deflated 52%)
#   adding: content/models/official/nlp/xlnet/README.md (deflated 39%)
#   adding: content/models/official/nlp/xlnet/data_utils.py (deflated 75%)
#   adding: content/models/official/nlp/xlnet/xlnet_config.py (deflated 64%)
#   adding: content/models/official/nlp/xlnet/training_utils.py (deflated 68%)
#   adding: content/models/official/nlp/xlnet/preprocess_utils.py (deflated 62%)
#   adding: content/models/official/nlp/xlnet/preprocess_squad_data.py (deflated 65%)
#   adding: content/models/official/nlp/xlnet/preprocess_pretrain_data.py (deflated 73%)
#   adding: content/models/official/nlp/xlnet/preprocess_classification_data.py (deflated 74%)
#   adding: content/models/official/nlp/xlnet/common_flags.py (deflated 67%)
#   adding: content/models/official/nlp/xlnet/optimization.py (deflated 65%)
#   adding: content/models/official/nlp/bert_models.py (deflated 76%)
#   adding: content/models/official/nlp/__init__.py (stored 0%)
#   adding: content/models/official/nlp/modeling/ (stored 0%)
#   adding: content/models/official/nlp/modeling/losses/ (stored 0%)
#   adding: content/models/official/nlp/modeling/losses/__init__.py (deflated 52%)
#   adding: content/models/official/nlp/modeling/losses/weighted_sparse_categorical_crossentropy_test.py (deflated 82%)
#   adding: content/models/official/nlp/modeling/losses/weighted_sparse_categorical_crossentropy.py (deflated 69%)
#   adding: content/models/official/nlp/modeling/layers/ (stored 0%)
#   adding: content/models/official/nlp/modeling/layers/on_device_embedding.py (deflated 59%)
#   adding: content/models/official/nlp/modeling/layers/position_embedding.py (deflated 64%)
#   adding: content/models/official/nlp/modeling/layers/masked_softmax_test.py (deflated 69%)
#   adding: content/models/official/nlp/modeling/layers/__init__.py (deflated 53%)
#   adding: content/models/official/nlp/modeling/layers/attention.py (deflated 76%)
#   adding: content/models/official/nlp/modeling/layers/masked_softmax.py (deflated 55%)
#   adding: content/models/official/nlp/modeling/layers/dense_einsum.py (deflated 71%)
#   adding: content/models/official/nlp/modeling/layers/on_device_embedding_test.py (deflated 83%)
#   adding: content/models/official/nlp/modeling/layers/position_embedding_test.py (deflated 69%)
#   adding: content/models/official/nlp/modeling/layers/transformer.py (deflated 78%)
#   adding: content/models/official/nlp/modeling/layers/transformer_test.py (deflated 80%)
#   adding: content/models/official/nlp/modeling/layers/dense_einsum_test.py (deflated 73%)
#   adding: content/models/official/nlp/modeling/layers/attention_test.py (deflated 73%)
#   adding: content/models/official/nlp/modeling/__init__.py (stored 0%)
#   adding: content/models/official/nlp/modeling/networks/ (stored 0%)
#   adding: content/models/official/nlp/modeling/networks/transformer_encoder_test.py (deflated 74%)
#   adding: content/models/official/nlp/modeling/networks/bert_pretrainer.py (deflated 62%)
#   adding: content/models/official/nlp/modeling/networks/__init__.py (deflated 50%)
#   adding: content/models/official/nlp/modeling/networks/bert_classifier.py (deflated 57%)
#   adding: content/models/official/nlp/modeling/networks/classification_test.py (deflated 78%)
#   adding: content/models/official/nlp/modeling/networks/transformer_encoder.py (deflated 69%)
#   adding: content/models/official/nlp/modeling/networks/bert_classifier_test.py (deflated 65%)
#   adding: content/models/official/nlp/modeling/networks/masked_lm.py (deflated 66%)
#   adding: content/models/official/nlp/modeling/networks/bert_span_labeler.py (deflated 56%)
#   adding: content/models/official/nlp/modeling/networks/bert_span_labeler_test.py (deflated 68%)
#   adding: content/models/official/nlp/modeling/networks/masked_lm_test.py (deflated 79%)
#   adding: content/models/official/nlp/modeling/networks/classification.py (deflated 58%)
#   adding: content/models/official/nlp/modeling/networks/span_labeling.py (deflated 60%)
#   adding: content/models/official/nlp/modeling/networks/bert_pretrainer_test.py (deflated 67%)
#   adding: content/models/official/nlp/modeling/networks/span_labeling_test.py (deflated 77%)
#   adding: content/models/official/nlp/README.md (deflated 38%)
#   adding: content/models/official/nlp/bert_modeling.py (deflated 78%)
#   adding: content/models/official/nlp/bert/ (stored 0%)
#   adding: content/models/official/nlp/bert/tf1_checkpoint_converter_lib.py (deflated 69%)
#   adding: content/models/official/nlp/bert/run_classifier.py (deflated 71%)
#   adding: content/models/official/nlp/bert/run_squad.py (deflated 69%)
#   adding: content/models/official/nlp/bert/__init__.py (stored 0%)
#   adding: content/models/official/nlp/bert/tf2_encoder_checkpoint_converter.py (deflated 61%)
#   adding: content/models/official/nlp/bert/run_pretraining.py (deflated 66%)
#   adding: content/models/official/nlp/bert/create_finetuning_data.py (deflated 65%)
#   adding: content/models/official/nlp/bert/export_tfhub_test.py (deflated 60%)
#   adding: content/models/official/nlp/bert/model_saving_utils.py (deflated 62%)
#   adding: content/models/official/nlp/bert/squad_lib.py (deflated 74%)
#   adding: content/models/official/nlp/bert/tokenization_test.py (deflated 71%)
#   adding: content/models/official/nlp/bert/README.md (deflated 73%)
#   adding: content/models/official/nlp/bert/export_tfhub.py (deflated 61%)
#   adding: content/models/official/nlp/bert/tokenization.py (deflated 68%)
#   adding: content/models/official/nlp/bert/input_pipeline.py (deflated 75%)
#   adding: content/models/official/nlp/bert/create_pretraining_data.py (deflated 70%)
#   adding: content/models/official/nlp/bert/classifier_data_lib.py (deflated 76%)
#   adding: content/models/official/nlp/bert/common_flags.py (deflated 57%)
#   adding: content/models/official/nlp/optimization.py (deflated 69%)
#   adding: content/models/official/.gitignore (stored 0%)
#   adding: content/models/official/vision/ (stored 0%)
#   adding: content/models/official/vision/__init__.py (stored 0%)
#   adding: content/models/official/vision/image_classification/ (stored 0%)
#   adding: content/models/official/vision/image_classification/mnist_main.py (deflated 63%)
#   adding: content/models/official/vision/image_classification/resnet_imagenet_main.py (deflated 68%)
#   adding: content/models/official/vision/image_classification/resnet_ctl_imagenet_main.py (deflated 72%)
#   adding: content/models/official/vision/image_classification/__init__.py (stored 0%)
#   adding: content/models/official/vision/image_classification/common.py (deflated 69%)
#   adding: content/models/official/vision/image_classification/imagenet_preprocessing.py (deflated 69%)
#   adding: content/models/official/vision/image_classification/mnist_test.py (deflated 58%)
#   adding: content/models/official/vision/image_classification/resnet_cifar_model.py (deflated 77%)
#   adding: content/models/official/vision/image_classification/tfhub_export.py (deflated 54%)
#   adding: content/models/official/vision/image_classification/resnet_imagenet_test.py (deflated 81%)
#   adding: content/models/official/vision/image_classification/README.md (deflated 64%)
#   adding: content/models/official/vision/image_classification/cifar_preprocessing.py (deflated 60%)
#   adding: content/models/official/vision/image_classification/resnet_model.py (deflated 79%)
#   adding: content/models/official/vision/image_classification/resnet_ctl_imagenet_test.py (deflated 62%)
#   adding: content/models/official/vision/image_classification/common_test.py (deflated 65%)
#   adding: content/models/official/vision/image_classification/resnet_cifar_test.py (deflated 76%)
#   adding: content/models/official/vision/image_classification/resnet_cifar_main.py (deflated 66%)
#   adding: content/models/official/vision/detection/ (stored 0%)
#   adding: content/models/official/vision/detection/configs/ (stored 0%)
#   adding: content/models/official/vision/detection/configs/__init__.py (deflated 43%)
#   adding: content/models/official/vision/detection/configs/factory.py (deflated 47%)
#   adding: content/models/official/vision/detection/configs/retinanet_config.py (deflated 67%)
#   adding: content/models/official/vision/detection/__init__.py (stored 0%)
#   adding: content/models/official/vision/detection/executor/ (stored 0%)
#   adding: content/models/official/vision/detection/executor/__init__.py (deflated 43%)
#   adding: content/models/official/vision/detection/executor/detection_executor.py (deflated 67%)
#   adding: content/models/official/vision/detection/dataloader/ (stored 0%)
#   adding: content/models/official/vision/detection/dataloader/input_reader.py (deflated 62%)
#   adding: content/models/official/vision/detection/dataloader/__init__.py (deflated 43%)
#   adding: content/models/official/vision/detection/dataloader/mode_keys.py (deflated 48%)
#   adding: content/models/official/vision/detection/dataloader/anchor.py (deflated 74%)
#   adding: content/models/official/vision/detection/dataloader/retinanet_parser.py (deflated 76%)
#   adding: content/models/official/vision/detection/dataloader/factory.py (deflated 77%)
#   adding: content/models/official/vision/detection/dataloader/tf_example_decoder.py (deflated 72%)
#   adding: content/models/official/vision/detection/dataloader/shapemask_parser.py (deflated 75%)
#   adding: content/models/official/vision/detection/dataloader/maskrcnn_parser.py (deflated 74%)
#   adding: content/models/official/vision/detection/evaluation/ (stored 0%)
#   adding: content/models/official/vision/detection/evaluation/__init__.py (deflated 43%)
#   adding: content/models/official/vision/detection/evaluation/coco_utils.py (deflated 72%)
#   adding: content/models/official/vision/detection/evaluation/factory.py (deflated 52%)
#   adding: content/models/official/vision/detection/evaluation/coco_evaluator.py (deflated 74%)
#   adding: content/models/official/vision/detection/modeling/ (stored 0%)
#   adding: content/models/official/vision/detection/modeling/__init__.py (deflated 43%)
#   adding: content/models/official/vision/detection/modeling/losses.py (deflated 77%)
#   adding: content/models/official/vision/detection/modeling/base_model.py (deflated 67%)
#   adding: content/models/official/vision/detection/modeling/factory.py (deflated 46%)
#   adding: content/models/official/vision/detection/modeling/checkpoint_utils.py (deflated 64%)
#   adding: content/models/official/vision/detection/modeling/retinanet_model.py (deflated 69%)
#   adding: content/models/official/vision/detection/modeling/learning_rates.py (deflated 70%)
#   adding: content/models/official/vision/detection/modeling/architecture/ (stored 0%)
#   adding: content/models/official/vision/detection/modeling/architecture/nn_ops.py (deflated 65%)
#   adding: content/models/official/vision/detection/modeling/architecture/fpn.py (deflated 70%)
#   adding: content/models/official/vision/detection/modeling/architecture/__init__.py (deflated 43%)
#   adding: content/models/official/vision/detection/modeling/architecture/resnet.py (deflated 74%)
#   adding: content/models/official/vision/detection/modeling/architecture/heads.py (deflated 81%)
#   adding: content/models/official/vision/detection/modeling/architecture/factory.py (deflated 74%)
#   adding: content/models/official/vision/detection/modeling/architecture/identity.py (deflated 49%)
#   adding: content/models/official/vision/detection/README.md (deflated 55%)
#   adding: content/models/official/vision/detection/ops/ (stored 0%)
#   adding: content/models/official/vision/detection/ops/roi_ops.py (deflated 75%)
#   adding: content/models/official/vision/detection/ops/postprocess_ops.py (deflated 79%)
#   adding: content/models/official/vision/detection/ops/nms.py (deflated 69%)
#   adding: content/models/official/vision/detection/ops/spatial_transform_ops.py (deflated 73%)
#   adding: content/models/official/vision/detection/ops/sampling_ops.py (deflated 79%)
#   adding: content/models/official/vision/detection/main.py (deflated 71%)
#   adding: content/models/official/vision/detection/utils/ (stored 0%)
#   adding: content/models/official/vision/detection/utils/input_utils.py (deflated 77%)
#   adding: content/models/official/vision/detection/utils/autoaugment_utils.py (deflated 45%)
#   adding: content/models/official/vision/detection/utils/__init__.py (deflated 43%)
#   adding: content/models/official/vision/detection/utils/box_utils.py (deflated 78%)
#   adding: content/models/official/vision/detection/utils/object_detection/ (stored 0%)
#   adding: content/models/official/vision/detection/utils/object_detection/ops.py (deflated 58%)
#   adding: content/models/official/vision/detection/utils/object_detection/visualization_utils.py (deflated 75%)
#   adding: content/models/official/vision/detection/utils/object_detection/region_similarity_calculator.py (deflated 67%)
#   adding: content/models/official/vision/detection/utils/object_detection/__init__.py (deflated 43%)
#   adding: content/models/official/vision/detection/utils/object_detection/box_list.py (deflated 66%)
#   adding: content/models/official/vision/detection/utils/object_detection/argmax_matcher.py (deflated 71%)
#   adding: content/models/official/vision/detection/utils/object_detection/balanced_positive_negative_sampler.py (deflated 73%)
#   adding: content/models/official/vision/detection/utils/object_detection/matcher.py (deflated 72%)
#   adding: content/models/official/vision/detection/utils/object_detection/preprocessor.py (deflated 75%)
#   adding: content/models/official/vision/detection/utils/object_detection/box_list_ops.py (deflated 77%)
#   adding: content/models/official/vision/detection/utils/object_detection/faster_rcnn_box_coder.py (deflated 61%)
#   adding: content/models/official/vision/detection/utils/object_detection/shape_utils.py (deflated 62%)
#   adding: content/models/official/vision/detection/utils/object_detection/minibatch_sampler.py (deflated 58%)
#   adding: content/models/official/vision/detection/utils/object_detection/box_coder.py (deflated 65%)
#   adding: content/models/official/vision/detection/utils/object_detection/target_assigner.py (deflated 75%)
#   adding: content/models/official/vision/detection/utils/dataloader_utils.py (deflated 53%)
#   adding: content/models/official/vision/detection/utils/mask_utils.py (deflated 60%)
#   adding: content/models/official/vision/detection/utils/class_utils.py (deflated 48%)
#   adding: content/models/official/Dockerfile.gpu (deflated 39%)
#   adding: content/models/official/modeling/ (stored 0%)
#   adding: content/models/official/modeling/activations/ (stored 0%)
#   adding: content/models/official/modeling/activations/gelu.py (deflated 44%)
#   adding: content/models/official/modeling/activations/__init__.py (deflated 51%)
#   adding: content/models/official/modeling/activations/gelu_test.py (deflated 46%)
#   adding: content/models/official/modeling/activations/swish.py (deflated 60%)
#   adding: content/models/official/modeling/activations/swish_test.py (deflated 55%)
#   adding: content/models/official/modeling/__init__.py (stored 0%)
#   adding: content/models/official/modeling/hyperparams/ (stored 0%)
#   adding: content/models/official/modeling/hyperparams/params_dict_test.py (deflated 81%)
#   adding: content/models/official/modeling/hyperparams/params_dict.py (deflated 70%)
#   adding: content/models/official/modeling/hyperparams/__init__.py (stored 0%)
#   adding: content/models/official/modeling/model_training_utils_test.py (deflated 70%)
#   adding: content/models/official/modeling/training/ (stored 0%)
#   adding: content/models/official/modeling/training/__init__.py (stored 0%)
#   adding: content/models/official/modeling/training/distributed_executor.py (deflated 75%)
#   adding: content/models/official/modeling/tf_utils.py (deflated 63%)
#   adding: content/models/official/modeling/model_training_utils.py (deflated 70%)
#   adding: content/models/official/LICENSE (deflated 65%)
#   adding: content/models/official/README.md (deflated 57%)
#   adding: content/models/official/staging/ (stored 0%)
#   adding: content/models/official/staging/__init__.py (stored 0%)
#   adding: content/models/official/staging/shakespeare/ (stored 0%)
#   adding: content/models/official/staging/shakespeare/__init__.py (stored 0%)
#   adding: content/models/official/staging/shakespeare/shakespeare_main.py (deflated 66%)
#   adding: content/models/official/staging/shakespeare/shakespeare_benchmark.py (deflated 79%)
#   adding: content/models/official/staging/shakespeare/README.md (deflated 54%)
#   adding: content/models/official/recommendation/ (stored 0%)
#   adding: content/models/official/recommendation/ncf_keras_main.py (deflated 70%)
#   adding: content/models/official/recommendation/__init__.py (stored 0%)
#   adding: content/models/official/recommendation/run_tpu.sh (deflated 41%)
#   adding: content/models/official/recommendation/data_pipeline.py (deflated 74%)
#   adding: content/models/official/recommendation/ncf_test.py (deflated 79%)
#   adding: content/models/official/recommendation/run.sh (deflated 53%)
#   adding: content/models/official/recommendation/constants.py (deflated 55%)
#   adding: content/models/official/recommendation/ncf_input_pipeline.py (deflated 68%)
#   adding: content/models/official/recommendation/stat_utils.py (deflated 55%)
#   adding: content/models/official/recommendation/README.md (deflated 58%)
#   adding: content/models/official/recommendation/data_preprocessing.py (deflated 64%)
#   adding: content/models/official/recommendation/ncf_keras_benchmark.py (deflated 82%)
#   adding: content/models/official/recommendation/data_test.py (deflated 67%)
#   adding: content/models/official/recommendation/create_ncf_data.py (deflated 63%)
#   adding: content/models/official/recommendation/ncf_estimator_main.py (deflated 65%)
#   adding: content/models/official/recommendation/popen_helper.py (deflated 60%)
#   adding: content/models/official/recommendation/neumf_model.py (deflated 68%)
#   adding: content/models/official/recommendation/movielens.py (deflated 64%)
#   adding: content/models/official/recommendation/ncf_common.py (deflated 67%)
#   adding: content/models/official/benchmark/ (stored 0%)
#   adding: content/models/official/benchmark/xlnet_benchmark.py (deflated 73%)
#   adding: content/models/official/benchmark/__init__.py (stored 0%)
#   adding: content/models/official/benchmark/models/ (stored 0%)
#   adding: content/models/official/benchmark/models/__init__.py (stored 0%)
#   adding: content/models/official/benchmark/models/trivial_model.py (deflated 51%)
#   adding: content/models/official/benchmark/retinanet_benchmark.py (deflated 69%)
#   adding: content/models/official/benchmark/benchmark_uploader.py (deflated 72%)
#   adding: content/models/official/benchmark/keras_benchmark.py (deflated 62%)
#   adding: content/models/official/benchmark/bert_benchmark_utils.py (deflated 62%)
#   adding: content/models/official/benchmark/datastore/ (stored 0%)
#   adding: content/models/official/benchmark/datastore/schema/ (stored 0%)
#   adding: content/models/official/benchmark/datastore/schema/benchmark_run_status.json (deflated 51%)
#   adding: content/models/official/benchmark/datastore/schema/benchmark_metric.json (deflated 70%)
#   adding: content/models/official/benchmark/datastore/schema/benchmark_run.json (deflated 84%)
#   adding: content/models/official/benchmark/benchmark_uploader_main.py (deflated 56%)
#   adding: content/models/official/benchmark/benchmark_uploader_test.py (deflated 71%)
#   adding: content/models/official/benchmark/bert_squad_benchmark.py (deflated 81%)
#   adding: content/models/official/benchmark/keras_imagenet_benchmark.py (deflated 89%)
#   adding: content/models/official/benchmark/bert_benchmark.py (deflated 80%)
#   adding: content/models/official/benchmark/resnet_ctl_imagenet_benchmark.py (deflated 76%)
#   adding: content/models/official/benchmark/squad_evaluate_v1_1.py (deflated 61%)
#   adding: content/models/official/benchmark/keras_cifar_benchmark.py (deflated 86%)
#   adding: content/models/official/Dockerfile.cpu (deflated 41%)
#   adding: content/models/official/requirements.txt (deflated 32%)
#   adding: content/models/official/transformer/ (stored 0%)
#   adding: content/models/official/transformer/__init__.py (stored 0%)
#   adding: content/models/official/transformer/model/ (stored 0%)
#   adding: content/models/official/transformer/model/model_params.py (deflated 58%)
#   adding: content/models/official/transformer/model/__init__.py (stored 0%)
#   adding: content/models/official/transformer/model/beam_search_test.py (deflated 66%)
#   adding: content/models/official/transformer/model/model_utils.py (deflated 61%)
#   adding: content/models/official/transformer/model/ffn_layer.py (deflated 61%)
#   adding: content/models/official/transformer/model/transformer.py (deflated 75%)
#   adding: content/models/official/transformer/model/model_utils_test.py (deflated 64%)
#   adding: content/models/official/transformer/model/attention_layer.py (deflated 65%)
#   adding: content/models/official/transformer/model/embedding_layer.py (deflated 59%)
#   adding: content/models/official/transformer/model/beam_search.py (deflated 74%)
#   adding: content/models/official/transformer/transformer_main.py (deflated 70%)
#   adding: content/models/official/transformer/v2/ (stored 0%)
#   adding: content/models/official/transformer/v2/__init__.py (stored 0%)
#   adding: content/models/official/transformer/v2/optimizer.py (deflated 67%)
#   adding: content/models/official/transformer/v2/data_pipeline.py (deflated 66%)
#   adding: content/models/official/transformer/v2/transformer_benchmark.py (deflated 86%)
#   adding: content/models/official/transformer/v2/transformer_main.py (deflated 72%)
#   adding: content/models/official/transformer/v2/translate.py (deflated 64%)
#   adding: content/models/official/transformer/v2/ffn_layer.py (deflated 60%)
#   adding: content/models/official/transformer/v2/transformer.py (deflated 76%)
#   adding: content/models/official/transformer/v2/transformer_main_test.py (deflated 70%)
#   adding: content/models/official/transformer/v2/README.md (deflated 63%)
#   adding: content/models/official/transformer/v2/transformer_test.py (deflated 64%)
#   adding: content/models/official/transformer/v2/attention_layer.py (deflated 66%)
#   adding: content/models/official/transformer/v2/embedding_layer.py (deflated 62%)
#   adding: content/models/official/transformer/v2/misc.py (deflated 66%)
#   adding: content/models/official/transformer/v2/metrics.py (deflated 70%)
#   adding: content/models/official/transformer/v2/beam_search.py (deflated 64%)
#   adding: content/models/official/transformer/v2/transformer_layers_test.py (deflated 66%)
#   adding: content/models/official/transformer/translate.py (deflated 64%)
#   adding: content/models/official/transformer/compute_bleu_test.py (deflated 64%)
#   adding: content/models/official/transformer/compute_bleu.py (deflated 59%)
#   adding: content/models/official/transformer/README.md (deflated 67%)
#   adding: content/models/official/transformer/data_download.py (deflated 68%)
#   adding: content/models/official/transformer/transformer_estimator_benchmark.py (deflated 82%)
#   adding: content/models/official/transformer/utils/ (stored 0%)
#   adding: content/models/official/transformer/utils/tokenizer_test.py (deflated 71%)
#   adding: content/models/official/transformer/utils/__init__.py (stored 0%)
#   adding: content/models/official/transformer/utils/schedule.py (deflated 63%)
#   adding: content/models/official/transformer/utils/tokenizer.py (deflated 70%)
#   adding: content/models/official/transformer/utils/dataset.py (deflated 66%)
#   adding: content/models/official/transformer/utils/metrics.py (deflated 71%)
#   adding: content/models/official/transformer/utils/schedule_test.py (deflated 69%)
#   adding: content/models/official/utils/ (stored 0%)
#   adding: content/models/official/utils/__init__.py (stored 0%)
#   adding: content/models/official/utils/hyperparams_flags.py (deflated 62%)
#   adding: content/models/official/utils/flags/ (stored 0%)
#   adding: content/models/official/utils/flags/guidelines.md (deflated 55%)
#   adding: content/models/official/utils/flags/core.py (deflated 62%)
#   adding: content/models/official/utils/flags/_conventions.py (deflated 49%)
#   adding: content/models/official/utils/flags/__init__.py (stored 0%)
#   adding: content/models/official/utils/flags/_base.py (deflated 67%)
#   adding: content/models/official/utils/flags/_device.py (deflated 56%)
#   adding: content/models/official/utils/flags/_benchmark.py (deflated 66%)
#   adding: content/models/official/utils/flags/README.md (deflated 57%)
#   adding: content/models/official/utils/flags/_distribution.py (deflated 54%)
#   adding: content/models/official/utils/flags/_misc.py (deflated 50%)
#   adding: content/models/official/utils/flags/flags_test.py (deflated 72%)
#   adding: content/models/official/utils/flags/_performance.py (deflated 70%)
#   adding: content/models/official/utils/misc/ (stored 0%)
#   adding: content/models/official/utils/misc/__init__.py (stored 0%)
#   adding: content/models/official/utils/misc/model_helpers_test.py (deflated 72%)
#   adding: content/models/official/utils/misc/model_helpers.py (deflated 60%)
#   adding: content/models/official/utils/misc/callstack_sampler.py (deflated 61%)
#   adding: content/models/official/utils/misc/distribution_utils.py (deflated 71%)
#   adding: content/models/official/utils/misc/distribution_utils_test.py (deflated 65%)
#   adding: content/models/official/utils/misc/tpu_lib.py (deflated 50%)
#   adding: content/models/official/utils/misc/keras_utils.py (deflated 68%)
#   adding: content/models/official/utils/logs/ (stored 0%)
#   adding: content/models/official/utils/logs/cloud_lib_test.py (deflated 52%)
#   adding: content/models/official/utils/logs/guidelines.md (deflated 54%)
#   adding: content/models/official/utils/logs/hooks_helper_test.py (deflated 62%)
#   adding: content/models/official/utils/logs/__init__.py (stored 0%)
#   adding: content/models/official/utils/logs/mlperf_helper.py (deflated 61%)
#   adding: content/models/official/utils/logs/cloud_lib.py (deflated 45%)
#   adding: content/models/official/utils/logs/logger.py (deflated 73%)
#   adding: content/models/official/utils/logs/hooks_test.py (deflated 71%)
#   adding: content/models/official/utils/logs/hooks.py (deflated 65%)
#   adding: content/models/official/utils/logs/hooks_helper.py (deflated 66%)
#   adding: content/models/official/utils/logs/logger_test.py (deflated 78%)
#   adding: content/models/official/utils/logs/metric_hook.py (deflated 60%)
#   adding: content/models/official/utils/logs/metric_hook_test.py (deflated 80%)
#   adding: content/models/official/utils/testing/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/dense/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/dense/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/dense/model.ckpt.index (deflated 33%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/dense/expected_graph (deflated 81%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/dense/results.json (deflated 58%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/dense/model.ckpt.data-00000-of-00001 (deflated 14%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/uniform_random/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/uniform_random/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/uniform_random/model.ckpt.index (deflated 38%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/uniform_random/expected_graph (deflated 57%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/uniform_random/results.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/reference_data_test/uniform_random/model.ckpt.data-00000-of-00001 (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-2_width-8_channels-4/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-2_width-8_channels-4/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-2_width-8_channels-4/model.ckpt.index (deflated 44%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-2_width-8_channels-4/expected_graph (deflated 85%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-2_width-8_channels-4/results.json (deflated 38%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-2_width-8_channels-4/model.ckpt.data-00000-of-00001 (deflated 11%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-1_width-8_channels-4/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-1_width-8_channels-4/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-1_width-8_channels-4/model.ckpt.index (deflated 51%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-1_width-8_channels-4/expected_graph (deflated 88%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-1_width-8_channels-4/results.json (deflated 35%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-1_width-8_channels-4/model.ckpt.data-00000-of-00001 (deflated 12%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-2_width-8_channels-4/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-2_width-8_channels-4/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-2_width-8_channels-4/model.ckpt.index (deflated 40%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-2_width-8_channels-4/expected_graph (deflated 85%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-2_width-8_channels-4/results.json (deflated 38%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-2_width-8_channels-4/model.ckpt.data-00000-of-00001 (deflated 11%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-1_width-8_channels-4/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-1_width-8_channels-4/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-1_width-8_channels-4/model.ckpt.index (deflated 44%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-1_width-8_channels-4/expected_graph (deflated 85%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-1_width-8_channels-4/results.json (deflated 38%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_version-1_width-8_channels-4/model.ckpt.data-00000-of-00001 (deflated 11%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_version-2_width-8_channels-4/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_version-2_width-8_channels-4/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_version-2_width-8_channels-4/model.ckpt.index (deflated 47%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_version-2_width-8_channels-4/expected_graph (deflated 87%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_version-2_width-8_channels-4/results.json (deflated 37%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_version-2_width-8_channels-4/model.ckpt.data-00000-of-00001 (deflated 12%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch_norm/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch_norm/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch_norm/model.ckpt.index (deflated 32%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch_norm/expected_graph (deflated 80%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch_norm/results.json (deflated 37%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch_norm/model.ckpt.data-00000-of-00001 (deflated 12%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-2_width-8_channels-4/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-2_width-8_channels-4/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-2_width-8_channels-4/model.ckpt.index (deflated 47%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-2_width-8_channels-4/expected_graph (deflated 87%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-2_width-8_channels-4/results.json (deflated 35%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_projection_version-2_width-8_channels-4/model.ckpt.data-00000-of-00001 (deflated 12%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-1_width-8_channels-4/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-1_width-8_channels-4/tf_version.json (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-1_width-8_channels-4/model.ckpt.index (deflated 50%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-1_width-8_channels-4/expected_graph (deflated 87%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-1_width-8_channels-4/results.json (deflated 35%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_building_projection_version-1_width-8_channels-4/model.ckpt.data-00000-of-00001 (deflated 11%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_version-1_width-8_channels-4/ (stored 0%)
#   adding: content/models/official/utils/testing/reference_data/resnet/batch-size-32_bottleneck_version-1_width-8_channels-4/tf_version.json (stored 0%)
# ...
#   adding: content/models/research/lstm_object_detection/g3doc/Interleaved_Intro.png (deflated 1%)
#   adding: content/models/research/lstm_object_detection/g3doc/lstm_ssd_intro.png (deflated 1%)
#   adding: content/models/research/lstm_object_detection/utils/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/utils/config_util.py (deflated 70%)
#   adding: content/models/research/lstm_object_detection/utils/config_util_test.py (deflated 71%)
#   adding: content/models/research/lstm_object_detection/utils/__init__.py (stored 0%)
#   adding: content/models/research/setup.py (deflated 39%)
#   adding: content/models/research/compression/ (stored 0%)
#   adding: content/models/research/compression/README.md (deflated 44%)
#   adding: content/models/research/compression/entropy_coder/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/configs/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/configs/synthetic/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/configs/synthetic/train_config.json (deflated 22%)
#   adding: content/models/research/compression/entropy_coder/configs/synthetic/input_config.json (deflated 11%)
#   adding: content/models/research/compression/entropy_coder/configs/synthetic/model_config.json (deflated 17%)
#   adding: content/models/research/compression/entropy_coder/configs/gru_prime3/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/configs/gru_prime3/model_config.json (deflated 16%)
#   adding: content/models/research/compression/entropy_coder/core/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/core/entropy_coder_single.py (deflated 59%)
#   adding: content/models/research/compression/entropy_coder/core/config_helper.py (deflated 55%)
#   adding: content/models/research/compression/entropy_coder/core/code_loader.py (deflated 54%)
#   adding: content/models/research/compression/entropy_coder/core/entropy_coder_train.py (deflated 67%)
#   adding: content/models/research/compression/entropy_coder/__init__.py (stored 0%)
#   adding: content/models/research/compression/entropy_coder/lib/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_entropy_coding_test.py (deflated 54%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_lstm_test.py (deflated 71%)
#   adding: content/models/research/compression/entropy_coder/lib/__init__.py (stored 0%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_operator_test.py (deflated 54%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_entropy_coding.py (deflated 49%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_std_test.py (deflated 75%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_masked_conv2d.py (deflated 76%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_binarizer.py (deflated 47%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks.py (deflated 51%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_masked_conv2d_test.py (deflated 78%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_lstm.py (deflated 71%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_operator.py (deflated 62%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_masked_conv2d_lstm.py (deflated 57%)
#   adding: content/models/research/compression/entropy_coder/lib/block_util.py (deflated 65%)
#   adding: content/models/research/compression/entropy_coder/lib/blocks_std.py (deflated 70%)
#   adding: content/models/research/compression/entropy_coder/lib/block_base.py (deflated 65%)
#   adding: content/models/research/compression/entropy_coder/model/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/model/__init__.py (stored 0%)
#   adding: content/models/research/compression/entropy_coder/model/model_factory.py (deflated 58%)
#   adding: content/models/research/compression/entropy_coder/model/entropy_coder_model.py (deflated 52%)
#   adding: content/models/research/compression/entropy_coder/progressive/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/progressive/__init__.py (stored 0%)
#   adding: content/models/research/compression/entropy_coder/progressive/progressive.py (deflated 69%)
#   adding: content/models/research/compression/entropy_coder/README.md (deflated 60%)
#   adding: content/models/research/compression/entropy_coder/all_models/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/all_models/__init__.py (stored 0%)
#   adding: content/models/research/compression/entropy_coder/all_models/all_models.py (deflated 44%)
#   adding: content/models/research/compression/entropy_coder/all_models/all_models_test.py (deflated 58%)
#   adding: content/models/research/compression/entropy_coder/dataset/ (stored 0%)
#   adding: content/models/research/compression/entropy_coder/dataset/gen_synthetic_single.py (deflated 50%)
#   adding: content/models/research/compression/entropy_coder/dataset/synthetic_model.py (deflated 55%)
#   adding: content/models/research/compression/entropy_coder/dataset/gen_synthetic_dataset.py (deflated 56%)
#   adding: content/models/research/compression/image_encoder/ (stored 0%)
#   adding: content/models/research/compression/image_encoder/decoder.py (deflated 61%)
#   adding: content/models/research/compression/image_encoder/encoder.py (deflated 58%)
#   adding: content/models/research/compression/image_encoder/msssim.py (deflated 66%)
#   adding: content/models/research/compression/image_encoder/README.md (deflated 52%)
#   adding: content/models/research/compression/image_encoder/example.png (deflated 48%)
#   adding: content/models/research/tensorrt/ (stored 0%)
#   adding: content/models/research/tensorrt/README.md (deflated 47%)
#   adding: content/models/research/fivo/ (stored 0%)
#   adding: content/models/research/fivo/bin/ (stored 0%)
#   adding: content/models/research/fivo/bin/run_eval.sh (deflated 44%)
#   adding: content/models/research/fivo/bin/run_sample.sh (deflated 45%)
#   adding: content/models/research/fivo/bin/run_train.sh (deflated 44%)
#   adding: content/models/research/fivo/bin/download_pianorolls.sh (deflated 51%)
#   adding: content/models/research/fivo/bin/run_tests.sh (deflated 53%)
#   adding: content/models/research/fivo/.gitignore (deflated 45%)
#   adding: content/models/research/fivo/run_fivo.py (deflated 70%)
#   adding: content/models/research/fivo/README.md (deflated 62%)
#   adding: content/models/research/fivo/.gitattributes (deflated 13%)
#   adding: content/models/research/fivo/experimental/ (stored 0%)
#   adding: content/models/research/fivo/experimental/data.py (deflated 74%)
#   adding: content/models/research/fivo/experimental/bounds.py (deflated 80%)
#   adding: content/models/research/fivo/experimental/train.py (deflated 77%)
#   adding: content/models/research/fivo/experimental/run.sh (deflated 49%)
#   adding: content/models/research/fivo/experimental/README.md (deflated 4%)
#   adding: content/models/research/fivo/experimental/models.py (deflated 86%)
#   adding: content/models/research/fivo/experimental/summary_utils.py (deflated 71%)
#   adding: content/models/research/fivo/fivo/ (stored 0%)
#   adding: content/models/research/fivo/fivo/ghmm_runners.py (deflated 73%)
#   adding: content/models/research/fivo/fivo/__init__.py (stored 0%)
#   adding: content/models/research/fivo/fivo/data/ (stored 0%)
#   adding: content/models/research/fivo/fivo/data/calculate_pianoroll_mean.py (deflated 55%)
#   adding: content/models/research/fivo/fivo/data/__init__.py (stored 0%)
#   adding: content/models/research/fivo/fivo/data/datasets_test.py (deflated 82%)
#   adding: content/models/research/fivo/fivo/data/create_timit_dataset.py (deflated 63%)
#   adding: content/models/research/fivo/fivo/data/datasets.py (deflated 76%)
#   adding: content/models/research/fivo/fivo/bounds_test.py (deflated 73%)
#   adding: content/models/research/fivo/fivo/models/ (stored 0%)
#   adding: content/models/research/fivo/fivo/models/srnn_test.py (deflated 70%)
#   adding: content/models/research/fivo/fivo/models/__init__.py (stored 0%)
#   adding: content/models/research/fivo/fivo/models/ghmm.py (deflated 76%)
#   adding: content/models/research/fivo/fivo/models/srnn.py (deflated 75%)
#   adding: content/models/research/fivo/fivo/models/base.py (deflated 72%)
#   adding: content/models/research/fivo/fivo/models/ghmm_test.py (deflated 82%)
#   adding: content/models/research/fivo/fivo/models/vrnn_test.py (deflated 72%)
#   adding: content/models/research/fivo/fivo/models/vrnn.py (deflated 75%)
#   adding: content/models/research/fivo/fivo/bounds.py (deflated 76%)
#   adding: content/models/research/fivo/fivo/ghmm_runners_test.py (deflated 68%)
#   adding: content/models/research/fivo/fivo/runners_test.py (deflated 79%)
#   adding: content/models/research/fivo/fivo/nested_utils.py (deflated 67%)
#   adding: content/models/research/fivo/fivo/runners.py (deflated 74%)
#   adding: content/models/research/fivo/fivo/smc_test.py (deflated 77%)
#   adding: content/models/research/fivo/fivo/nested_utils_test.py (deflated 70%)
#   adding: content/models/research/fivo/fivo/test_utils.py (deflated 77%)
#   adding: content/models/research/fivo/fivo/smc.py (deflated 71%)
#   adding: content/models/research/fivo/fivo/test_data/ (stored 0%)
#   adding: content/models/research/fivo/fivo/test_data/tiny_speech_dataset.tfrecord (deflated 48%)
#   adding: content/models/research/fivo/fivo/test_data/tiny_pianoroll.pkl (deflated 90%)
#   adding: content/models/research/learning_to_remember_rare_events/ (stored 0%)
#   adding: content/models/research/learning_to_remember_rare_events/train.py (deflated 68%)
#   adding: content/models/research/learning_to_remember_rare_events/README.md (deflated 50%)
#   adding: content/models/research/learning_to_remember_rare_events/memory.py (deflated 73%)
#   adding: content/models/research/learning_to_remember_rare_events/data_utils.py (deflated 67%)
#   adding: content/models/research/learning_to_remember_rare_events/model.py (deflated 73%)
#   adding: content/models/research/pcl_rl/ (stored 0%)
#   adding: content/models/research/pcl_rl/gym_wrapper.py (deflated 62%)
#   adding: content/models/research/pcl_rl/trainer.py (deflated 73%)
#   adding: content/models/research/pcl_rl/replay_buffer.py (deflated 70%)
#   adding: content/models/research/pcl_rl/trust_region.py (deflated 65%)
#   adding: content/models/research/pcl_rl/env_spec.py (deflated 71%)
#   adding: content/models/research/pcl_rl/controller.py (deflated 74%)
#   adding: content/models/research/pcl_rl/full_episode_objective.py (deflated 61%)
#   adding: content/models/research/pcl_rl/objective.py (deflated 81%)
#   adding: content/models/research/pcl_rl/README.md (deflated 65%)
#   adding: content/models/research/pcl_rl/baseline.py (deflated 73%)
#   adding: content/models/research/pcl_rl/expert_paths.py (deflated 71%)
#   adding: content/models/research/pcl_rl/model.py (deflated 78%)
#   adding: content/models/research/pcl_rl/policy.py (deflated 78%)
#   adding: content/models/research/pcl_rl/optimizers.py (deflated 72%)
#   adding: content/models/research/adversarial_crypto/ (stored 0%)
#   adding: content/models/research/adversarial_crypto/train_eval.py (deflated 61%)
#   adding: content/models/research/adversarial_crypto/README.md (deflated 50%)
#   adding: content/models/research/domain_adaptation/ (stored 0%)
#   adding: content/models/research/domain_adaptation/__init__.py (stored 0%)
#   adding: content/models/research/domain_adaptation/datasets/ (stored 0%)
#   adding: content/models/research/domain_adaptation/datasets/dataset_factory.py (deflated 63%)
#   adding: content/models/research/domain_adaptation/datasets/BUILD (deflated 61%)
#   adding: content/models/research/domain_adaptation/datasets/__init__.py (stored 0%)
#   adding: content/models/research/domain_adaptation/datasets/download_and_convert_mnist_m.py (deflated 65%)
#   adding: content/models/research/domain_adaptation/datasets/mnist_m.py (deflated 54%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/ (stored 0%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/pixelda_preprocess_test.py (deflated 63%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/pixelda_train.py (deflated 73%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/BUILD (deflated 74%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/pixelda_utils.py (deflated 71%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/pixelda_task_towers.py (deflated 79%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/pixelda_model.py (deflated 75%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/pixelda_losses.py (deflated 74%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/pixelda_eval.py (deflated 73%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/README.md (stored 0%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/hparams.py (deflated 65%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/pixelda_preprocess.py (deflated 63%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/baselines/ (stored 0%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/baselines/BUILD (deflated 72%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/baselines/baseline_eval.py (deflated 63%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/baselines/baseline_train.py (deflated 64%)
#   adding: content/models/research/domain_adaptation/pixel_domain_adaptation/baselines/README.md (deflated 67%)
#   adding: content/models/research/domain_adaptation/README.md (deflated 59%)
#   adding: content/models/research/domain_adaptation/WORKSPACE (stored 0%)
#   adding: content/models/research/domain_adaptation/domain_separation/ (stored 0%)
#   adding: content/models/research/domain_adaptation/domain_separation/grl_op_grads.py (deflated 49%)
#   adding: content/models/research/domain_adaptation/domain_separation/BUILD (deflated 81%)
#   adding: content/models/research/domain_adaptation/domain_separation/__init__.py (stored 0%)
#   adding: content/models/research/domain_adaptation/domain_separation/dsn.py (deflated 73%)
#   adding: content/models/research/domain_adaptation/domain_separation/_grl_ops.so (deflated 71%)
#   adding: content/models/research/domain_adaptation/domain_separation/dsn_eval.py (deflated 63%)
#   adding: content/models/research/domain_adaptation/domain_separation/losses.py (deflated 72%)
#   adding: content/models/research/domain_adaptation/domain_separation/models_test.py (deflated 77%)
#   adding: content/models/research/domain_adaptation/domain_separation/grl_ops.py (deflated 48%)
#   adding: content/models/research/domain_adaptation/domain_separation/dsn_train.py (deflated 72%)
#   adding: content/models/research/domain_adaptation/domain_separation/models.py (deflated 83%)
#   adding: content/models/research/domain_adaptation/domain_separation/grl_ops_test.py (deflated 61%)
#   adding: content/models/research/domain_adaptation/domain_separation/dsn_test.py (deflated 78%)
#   adding: content/models/research/domain_adaptation/domain_separation/grl_op_shapes.py (deflated 43%)
#   adding: content/models/research/domain_adaptation/domain_separation/utils.py (deflated 64%)
#   adding: content/models/research/domain_adaptation/domain_separation/losses_test.py (deflated 68%)
#   adding: content/models/research/domain_adaptation/domain_separation/grl_op_kernels.cc (deflated 51%)
#   adding: content/models/research/domain_adaptation/domain_separation/grl_ops.cc (deflated 47%)
#   adding: content/models/CONTRIBUTING.md (deflated 52%)
#   adding: content/models/CODEOWNERS (deflated 56%)
#   adding: content/models/ISSUE_TEMPLATE.md (deflated 49%)
